# %%
import os
os.chdir('../')

# %%
import pandas as pd
from pathlib import Path
from PIL import Image
import json
import random

# %%
root_path = Path('./data/')

# %%
style_df = pd.read_csv(root_path / 'metadata' / 'style.csv')
style_df = style_df[~style_df['File_name'].isna()]
style_df = style_df.sort_values('File_name').reset_index(drop=True)

content_df = pd.read_csv(root_path / 'metadata' / 'content.csv')
content_df = content_df[~content_df['File_name'].isna()]
content_df = content_df.sort_values('File_name').reset_index(drop=True)

# %%
content_df.head()
# Out:
#                                        Title                 Author  \
# 0                Acrobat and young harlequin          Pablo Picasso
# 1                       The Creation of Adam           Michelangelo
# 2  Self-Portrait as the Allegory of Painting  Artemisia Gentileschi
# 3                            American Gothic             Grant Wood
# 4                          Amor Vincit Omnia             Caravaggio
#
#   Orientation  Resolution                        File_name Looks_good  \
# 0    Portrait  684 × 1230  acrobat_and_young_harlequin.jpg        NaN
# 1   Landscape    1920x871                        adamo.jpg        NaN
# 2    Portrait    818x1080                    allegorie.jpg          Y
# 3    Portrait   1790x2160              american_gothic.jpg          Y
# 4    Portrait   1151x1614            amor_vincit_omnia.jpg        TBD
#
#   Copyright Copyright link
# 0       NaN            NaN
# 1       NaN            NaN
# 2       NaN            NaN
# 3       NaN            NaN
# 4       NaN            NaN

# %%
style_df.head()
# Out:
#                     Title                   Author Resolution  \
# 0          Alpine Pasture  Margret Hofheinz-Döring   804x1024
# 1  Animals in a Landscape               Marc Franz   964x1024
# 2   Bed of Chrysanthemums             Claude Monet   688x1024
# 3                   Birds               Marc Franz   938x1024
# 4          Blue Black Fox               Marc Franz  1280x1015
#
#                     File_name  Notes  Strength  Copyright  Copyright link
# 0         alpine_pasture.jfif    NaN       NaN        NaN             NaN
# 1  animals_in_a_landscape.jpg    NaN       NaN        NaN             NaN
# 2   bed_of_chrysanthemums.jpg  Luigi       NaN        NaN             NaN
# 3                   birds.jpg    NaN       NaN        NaN             NaN
# 4          blue-black_fox.jpg    NaN       NaN        NaN             NaN

# %%
content_path = root_path / 'content-images'
style_path = root_path / 'style-images'

# %%
content = content_df[content_df['File_name']=='le_desespere.jpg'].iloc[0]
for j, style in style_df.iterrows():

    content_img_path = content_path / content['File_name']    
    style_img_path = style_path / style['File_name']
    output_name = f'{style["File_name"]}'.split('.')[0]

    print(f"Processing content image: {content['File_name']}")
    print(f"Processing style: {style['File_name']}")
    print(f"Saving image as {output_name}")
    
    try:
        # !python neural_style_transfer.py --content_img_name {content['File_name']} --style_img_name {style['File_name']} --output_img_name {output_name} --output_path test_style1
    except:
        print(style['File_name'])
    
    print()
# Out:
# Processing content image: le_desespere.jpg
# Processing style: alpine_pasture.jfif
# Saving image as alpine_pasture
# 2021-12-10 19:18:03,051 [DEBUG] {'content_img_name': 'le_desespere.jpg', 'style_img_name': 'alpine_pasture.jfif', 'output_img_name': 'alpine_pasture', 'output_path': 'test_style1', 'height': 500, 'content_weight': 100000.0, 'style_weight': 60000.0, 'tv_weight': 1.0, 'optimizer': 'lbfgs', 'model': 'vgg19', 'init_method': 'content', 'saving_freq': 50, 'content_images_dir': PosixPath('data/content-images'), 'style_images_dir': PosixPath('data/style-images'), 'output_img_dir': PosixPath('data/output-images'), 'images_path': PosixPath('data/test_style1/images'), 'gifs_path': PosixPath('data/test_style1/gifs'), 'img_format': (4, '.jpg')}
# 2021-12-10 19:18:03,052 [INFO] Starting training..
# 2021-12-10 19:18:03,617 [DEBUG] Using device cuda for training
# 2021-12-10 19:18:10,009 [DEBUG] Using vgg19 in the optimization procedure
# 2021-12-10 19:20:21,410 [DEBUG] Executed 1017 iterations
# 2021-12-10 19:20:21,410 [INFO] Training finished
# 2021-12-10 19:20:21,411 [INFO] Creating gif..
# 2021-12-10 19:20:30,150 [INFO] Copying data/output-images/combined_le_desespere_alpine_pasture/1000.jpg
# 2021-12-10 19:20:30,151 [INFO] Copying data/output-images/combined_le_desespere_alpine_pasture/out.gif
# 2021-12-10 19:20:30,151 [INFO] Copying to data/test_style1/gifs/galpine_pasture.gif
# 2021-12-10 19:20:30,161 [INFO] Time elapsed: 147.10990357398987
#
# Processing content image: le_desespere.jpg
# Processing style: animals_in_a_landscape.jpg
# Saving image as animals_in_a_landscape
# 2021-12-10 19:20:31,649 [DEBUG] {'content_img_name': 'le_desespere.jpg', 'style_img_name': 'animals_in_a_landscape.jpg', 'output_img_name': 'animals_in_a_landscape', 'output_path': 'test_style1', 'height': 500, 'content_weight': 100000.0, 'style_weight': 60000.0, 'tv_weight': 1.0, 'optimizer': 'lbfgs', 'model': 'vgg19', 'init_method': 'content', 'saving_freq': 50, 'content_images_dir': PosixPath('data/content-images'), 'style_images_dir': PosixPath('data/style-images'), 'output_img_dir': PosixPath('data/output-images'), 'images_path': PosixPath('data/test_style1/images'), 'gifs_path': PosixPath('data/test_style1/gifs'), 'img_format': (4, '.jpg')}
# 2021-12-10 19:20:31,649 [INFO] Starting training..
# 2021-12-10 19:20:32,216 [DEBUG] Using device cuda for training
# 2021-12-10 19:20:34,541 [DEBUG] Using vgg19 in the optimization procedure
# 2021-12-10 19:22:46,831 [DEBUG] Executed 1013 iterations
# 2021-12-10 19:22:46,831 [INFO] Training finished
# 2021-12-10 19:22:46,831 [INFO] Creating gif..
# 2021-12-10 19:22:56,861 [INFO] Copying data/output-images/combined_le_desespere_animals_in_a_landscape/1000.jpg
# 2021-12-10 19:22:56,862 [INFO] Copying data/output-images/combined_le_desespere_animals_in_a_landscape/out.gif
# 2021-12-10 19:22:56,862 [INFO] Copying to data/test_style1/gifs/ganimals_in_a_landscape.gif
# 2021-12-10 19:22:56,871 [INFO] Time elapsed: 145.2233283519745
#
# Processing content image: le_desespere.jpg
# Processing style: bed_of_chrysanthemums.jpg
# Saving image as bed_of_chrysanthemums
# 2021-12-10 19:22:58,339 [DEBUG] {'content_img_name': 'le_desespere.jpg', 'style_img_name': 'bed_of_chrysanthemums.jpg', 'output_img_name': 'bed_of_chrysanthemums', 'output_path': 'test_style1', 'height': 500, 'content_weight': 100000.0, 'style_weight': 60000.0, 'tv_weight': 1.0, 'optimizer': 'lbfgs', 'model': 'vgg19', 'init_method': 'content', 'saving_freq': 50, 'content_images_dir': PosixPath('data/content-images'), 'style_images_dir': PosixPath('data/style-images'), 'output_img_dir': PosixPath('data/output-images'), 'images_path': PosixPath('data/test_style1/images'), 'gifs_path': PosixPath('data/test_style1/gifs'), 'img_format': (4, '.jpg')}
# 2021-12-10 19:22:58,339 [INFO] Starting training..
# 2021-12-10 19:22:58,906 [DEBUG] Using device cuda for training
# 2021-12-10 19:23:01,190 [DEBUG] Using vgg19 in the optimization procedure
# 2021-12-10 19:25:11,923 [DEBUG] Executed 1017 iterations
# 2021-12-10 19:25:11,923 [INFO] Training finished
# 2021-12-10 19:25:11,923 [INFO] Creating gif..
# 2021-12-10 19:25:21,392 [INFO] Copying data/output-images/combined_le_desespere_bed_of_chrysanthemums/1000.jpg
# 2021-12-10 19:25:21,392 [INFO] Copying data/output-images/combined_le_desespere_bed_of_chrysanthemums/out.gif
# 2021-12-10 19:25:21,393 [INFO] Copying to data/test_style1/gifs/gbed_of_chrysanthemums.gif
# 2021-12-10 19:25:21,402 [INFO] Time elapsed: 143.0643436908722
#
# Processing content image: le_desespere.jpg
# Processing style: birds.jpg
# Saving image as birds
# 2021-12-10 19:25:22,771 [DEBUG] {'content_img_name': 'le_desespere.jpg', 'style_img_name': 'birds.jpg', 'output_img_name': 'birds', 'output_path': 'test_style1', 'height': 500, 'content_weight': 100000.0, 'style_weight': 60000.0, 'tv_weight': 1.0, 'optimizer': 'lbfgs', 'model': 'vgg19', 'init_method': 'content', 'saving_freq': 50, 'content_images_dir': PosixPath('data/content-images'), 'style_images_dir': PosixPath('data/style-images'), 'output_img_dir': PosixPath('data/output-images'), 'images_path': PosixPath('data/test_style1/images'), 'gifs_path': PosixPath('data/test_style1/gifs'), 'img_format': (4, '.jpg')}
# 2021-12-10 19:25:22,771 [INFO] Starting training..
# 2021-12-10 19:25:23,336 [DEBUG] Using device cuda for training
# 2021-12-10 19:25:25,626 [DEBUG] Using vgg19 in the optimization procedure
# 2021-12-10 19:27:38,106 [DEBUG] Executed 1015 iterations
# 2021-12-10 19:27:38,107 [INFO] Training finished
# 2021-12-10 19:27:38,107 [INFO] Creating gif..
# 2021-12-10 19:27:47,031 [INFO] Copying data/output-images/combined_le_desespere_birds/1000.jpg
# 2021-12-10 19:27:47,032 [INFO] Copying data/output-images/combined_le_desespere_birds/out.gif
# 2021-12-10 19:27:47,032 [INFO] Copying to data/test_style1/gifs/gbirds.gif
# 2021-12-10 19:27:47,041 [INFO] Time elapsed: 144.2707130908966
#
# Processing content image: le_desespere.jpg
# Processing style: blue-black_fox.jpg
# Saving image as blue-black_fox
# 2021-12-10 19:27:48,407 [DEBUG] {'content_img_name': 'le_desespere.jpg', 'style_img_name': 'blue-black_fox.jpg', 'output_img_name': 'blue-black_fox', 'output_path': 'test_style1', 'height': 500, 'content_weight': 100000.0, 'style_weight': 60000.0, 'tv_weight': 1.0, 'optimizer': 'lbfgs', 'model': 'vgg19', 'init_method': 'content', 'saving_freq': 50, 'content_images_dir': PosixPath('data/content-images'), 'style_images_dir': PosixPath('data/style-images'), 'output_img_dir': PosixPath('data/output-images'), 'images_path': PosixPath('data/test_style1/images'), 'gifs_path': PosixPath('data/test_style1/gifs'), 'img_format': (4, '.jpg')}
# 2021-12-10 19:27:48,407 [INFO] Starting training..
# 2021-12-10 19:27:48,977 [DEBUG] Using device cuda for training
# 2021-12-10 19:27:51,291 [DEBUG] Using vgg19 in the optimization procedure
# 2021-12-10 19:30:02,168 [DEBUG] Executed 1018 iterations
# 2021-12-10 19:30:02,169 [INFO] Training finished
# 2021-12-10 19:30:02,169 [INFO] Creating gif..
# 2021-12-10 19:30:12,388 [INFO] Copying data/output-images/combined_le_desespere_blue-black_fox/1000.jpg
# 2021-12-10 19:30:12,389 [INFO] Copying data/output-images/combined_le_desespere_blue-black_fox/out.gif
# 2021-12-10 19:30:12,389 [INFO] Copying to data/test_style1/gifs/gblue-black_fox.gif
# 2021-12-10 19:30:12,397 [INFO] Time elapsed: 143.9904556274414
#
# Processing content image: le_desespere.jpg
# Processing style: blue_horse.jpg
# Saving image as blue_horse
# 2021-12-10 19:30:13,741 [DEBUG] {'content_img_name': 'le_desespere.jpg', 'style_img_name': 'blue_horse.jpg', 'output_img_name': 'blue_horse', 'output_path': 'test_style1', 'height': 500, 'content_weight': 100000.0, 'style_weight': 60000.0, 'tv_weight': 1.0, 'optimizer': 'lbfgs', 'model': 'vgg19', 'init_method': 'content', 'saving_freq': 50, 'content_images_dir': PosixPath('data/content-images'), 'style_images_dir': PosixPath('data/style-images'), 'output_img_dir': PosixPath('data/output-images'), 'images_path': PosixPath('data/test_style1/images'), 'gifs_path': PosixPath('data/test_style1/gifs'), 'img_format': (4, '.jpg')}
# 2021-12-10 19:30:13,741 [INFO] Starting training..
# 2021-12-10 19:30:14,305 [DEBUG] Using device cuda for training
# 2021-12-10 19:30:16,662 [DEBUG] Using vgg19 in the optimization procedure
# 2021-12-10 19:32:28,255 [DEBUG] Executed 1012 iterations
# 2021-12-10 19:32:28,255 [INFO] Training finished
# 2021-12-10 19:32:28,256 [INFO] Creating gif..
# 2021-12-10 19:32:37,531 [INFO] Copying data/output-images/combined_le_desespere_blue_horse/1000.jpg
# 2021-12-10 19:32:37,532 [INFO] Copying data/output-images/combined_le_desespere_blue_horse/out.gif
# 2021-12-10 19:32:37,532 [INFO] Copying to data/test_style1/gifs/gblue_horse.gif
# 2021-12-10 19:32:37,541 [INFO] Time elapsed: 143.8009490966797
#
# Processing content image: le_desespere.jpg
# Processing style: blue_mountain.jfif
# Saving image as blue_mountain
# 2021-12-10 19:32:38,907 [DEBUG] {'content_img_name': 'le_desespere.jpg', 'style_img_name': 'blue_mountain.jfif', 'output_img_name': 'blue_mountain', 'output_path': 'test_style1', 'height': 500, 'content_weight': 100000.0, 'style_weight': 60000.0, 'tv_weight': 1.0, 'optimizer': 'lbfgs', 'model': 'vgg19', 'init_method': 'content', 'saving_freq': 50, 'content_images_dir': PosixPath('data/content-images'), 'style_images_dir': PosixPath('data/style-images'), 'output_img_dir': PosixPath('data/output-images'), 'images_path': PosixPath('data/test_style1/images'), 'gifs_path': PosixPath('data/test_style1/gifs'), 'img_format': (4, '.jpg')}
# 2021-12-10 19:32:38,907 [INFO] Starting training..
# 2021-12-10 19:32:39,477 [DEBUG] Using device cuda for training
# 2021-12-10 19:32:41,770 [DEBUG] Using vgg19 in the optimization procedure
# 2021-12-10 19:34:52,771 [DEBUG] Executed 1013 iterations
# 2021-12-10 19:34:52,771 [INFO] Training finished
# 2021-12-10 19:34:52,772 [INFO] Creating gif..
# 2021-12-10 19:35:02,752 [INFO] Copying data/output-images/combined_le_desespere_blue_mountain/1000.jpg
# 2021-12-10 19:35:02,753 [INFO] Copying data/output-images/combined_le_desespere_blue_mountain/out.gif
# 2021-12-10 19:35:02,753 [INFO] Copying to data/test_style1/gifs/gblue_mountain.gif
# 2021-12-10 19:35:02,761 [INFO] Time elapsed: 143.85479021072388
#
# Processing content image: le_desespere.jpg
# Processing style: blue_room.jpg
# Saving image as blue_room
# 2021-12-10 19:35:04,128 [DEBUG] {'content_img_name': 'le_desespere.jpg', 'style_img_name': 'blue_room.jpg', 'output_img_name': 'blue_room', 'output_path': 'test_style1', 'height': 500, 'content_weight': 100000.0, 'style_weight': 60000.0, 'tv_weight': 1.0, 'optimizer': 'lbfgs', 'model': 'vgg19', 'init_method': 'content', 'saving_freq': 50, 'content_images_dir': PosixPath('data/content-images'), 'style_images_dir': PosixPath('data/style-images'), 'output_img_dir': PosixPath('data/output-images'), 'images_path': PosixPath('data/test_style1/images'), 'gifs_path': PosixPath('data/test_style1/gifs'), 'img_format': (4, '.jpg')}
# 2021-12-10 19:35:04,128 [INFO] Starting training..
# 2021-12-10 19:35:04,697 [DEBUG] Using device cuda for training
# 2021-12-10 19:35:07,001 [DEBUG] Using vgg19 in the optimization procedure
# 2021-12-10 19:37:18,803 [DEBUG] Executed 1016 iterations
# 2021-12-10 19:37:18,803 [INFO] Training finished
# 2021-12-10 19:37:18,803 [INFO] Creating gif..
# 2021-12-10 19:37:27,430 [INFO] Copying data/output-images/combined_le_desespere_blue_room/1000.jpg
# 2021-12-10 19:37:27,430 [INFO] Copying data/output-images/combined_le_desespere_blue_room/out.gif
# 2021-12-10 19:37:27,430 [INFO] Copying to data/test_style1/gifs/gblue_room.gif
# 2021-12-10 19:37:27,440 [INFO] Time elapsed: 143.31267619132996
#
# Processing content image: le_desespere.jpg
# Processing style: coast_scene,_isles_of_shoals.jpg
# Saving image as coast_scene,_isles_of_shoals
# 2021-12-10 19:37:28,809 [DEBUG] {'content_img_name': 'le_desespere.jpg', 'style_img_name': 'coast_scene,_isles_of_shoals.jpg', 'output_img_name': 'coast_scene,_isles_of_shoals', 'output_path': 'test_style1', 'height': 500, 'content_weight': 100000.0, 'style_weight': 60000.0, 'tv_weight': 1.0, 'optimizer': 'lbfgs', 'model': 'vgg19', 'init_method': 'content', 'saving_freq': 50, 'content_images_dir': PosixPath('data/content-images'), 'style_images_dir': PosixPath('data/style-images'), 'output_img_dir': PosixPath('data/output-images'), 'images_path': PosixPath('data/test_style1/images'), 'gifs_path': PosixPath('data/test_style1/gifs'), 'img_format': (4, '.jpg')}
# 2021-12-10 19:37:28,810 [INFO] Starting training..
# 2021-12-10 19:37:29,378 [DEBUG] Using device cuda for training
# 2021-12-10 19:37:31,699 [DEBUG] Using vgg19 in the optimization procedure
# 2021-12-10 19:39:43,171 [DEBUG] Executed 1016 iterations
# 2021-12-10 19:39:43,171 [INFO] Training finished
# 2021-12-10 19:39:43,172 [INFO] Creating gif..
# 2021-12-10 19:39:52,273 [INFO] Copying data/output-images/combined_le_desespere_coast_scene,_isles_of_shoals/1000.jpg
# 2021-12-10 19:39:52,274 [INFO] Copying data/output-images/combined_le_desespere_coast_scene,_isles_of_shoals/out.gif
# 2021-12-10 19:39:52,274 [INFO] Copying to data/test_style1/gifs/gcoast_scene,_isles_of_shoals.gif
# 2021-12-10 19:39:52,284 [INFO] Time elapsed: 143.47554206848145
#
# Processing content image: le_desespere.jpg
# Processing style: cocina_alpina.jpg
# Saving image as cocina_alpina
# 2021-12-10 19:39:53,745 [DEBUG] {'content_img_name': 'le_desespere.jpg', 'style_img_name': 'cocina_alpina.jpg', 'output_img_name': 'cocina_alpina', 'output_path': 'test_style1', 'height': 500, 'content_weight': 100000.0, 'style_weight': 60000.0, 'tv_weight': 1.0, 'optimizer': 'lbfgs', 'model': 'vgg19', 'init_method': 'content', 'saving_freq': 50, 'content_images_dir': PosixPath('data/content-images'), 'style_images_dir': PosixPath('data/style-images'), 'output_img_dir': PosixPath('data/output-images'), 'images_path': PosixPath('data/test_style1/images'), 'gifs_path': PosixPath('data/test_style1/gifs'), 'img_format': (4, '.jpg')}
# 2021-12-10 19:39:53,745 [INFO] Starting training..
# 2021-12-10 19:39:54,296 [DEBUG] Using device cuda for training
# 2021-12-10 19:39:56,579 [DEBUG] Using vgg19 in the optimization procedure
# 2021-12-10 19:42:08,013 [DEBUG] Executed 1013 iterations
# 2021-12-10 19:42:08,014 [INFO] Training finished
# 2021-12-10 19:42:08,014 [INFO] Creating gif..
# 2021-12-10 19:42:18,563 [INFO] Copying data/output-images/combined_le_desespere_cocina_alpina/1000.jpg
# 2021-12-10 19:42:18,563 [INFO] Copying data/output-images/combined_le_desespere_cocina_alpina/out.gif
# 2021-12-10 19:42:18,563 [INFO] Copying to data/test_style1/gifs/gcocina_alpina.gif
# 2021-12-10 19:42:18,574 [INFO] Time elapsed: 144.829256772995
#
# Processing content image: le_desespere.jpg
# Processing style: composition_II_with_red_blue_and_yellow.jpg
# Saving image as composition_II_with_red_blue_and_yellow
# 2021-12-10 19:42:19,947 [DEBUG] {'content_img_name': 'le_desespere.jpg', 'style_img_name': 'composition_II_with_red_blue_and_yellow.jpg', 'output_img_name': 'composition_II_with_red_blue_and_yellow', 'output_path': 'test_style1', 'height': 500, 'content_weight': 100000.0, 'style_weight': 60000.0, 'tv_weight': 1.0, 'optimizer': 'lbfgs', 'model': 'vgg19', 'init_method': 'content', 'saving_freq': 50, 'content_images_dir': PosixPath('data/content-images'), 'style_images_dir': PosixPath('data/style-images'), 'output_img_dir': PosixPath('data/output-images'), 'images_path': PosixPath('data/test_style1/images'), 'gifs_path': PosixPath('data/test_style1/gifs'), 'img_format': (4, '.jpg')}
# 2021-12-10 19:42:19,947 [INFO] Starting training..
# 2021-12-10 19:42:20,517 [DEBUG] Using device cuda for training
# 2021-12-10 19:42:22,843 [DEBUG] Using vgg19 in the optimization procedure
# 2021-12-10 19:44:33,517 [DEBUG] Executed 1008 iterations
# 2021-12-10 19:44:33,517 [INFO] Training finished
# 2021-12-10 19:44:33,517 [INFO] Creating gif..
# 2021-12-10 19:44:42,378 [INFO] Copying data/output-images/combined_le_desespere_composition_II_with_red_blue_and_yellow/1000.jpg
# 2021-12-10 19:44:42,379 [INFO] Copying data/output-images/combined_le_desespere_composition_II_with_red_blue_and_yellow/out.gif
# 2021-12-10 19:44:42,379 [INFO] Copying to data/test_style1/gifs/gcomposition_II_with_red_blue_and_yellow.gif
# 2021-12-10 19:44:42,387 [INFO] Time elapsed: 142.44060039520264
#
# Processing content image: le_desespere.jpg
# Processing style: composition_viii.jpg
# Saving image as composition_viii
# 2021-12-10 19:44:43,749 [DEBUG] {'content_img_name': 'le_desespere.jpg', 'style_img_name': 'composition_viii.jpg', 'output_img_name': 'composition_viii', 'output_path': 'test_style1', 'height': 500, 'content_weight': 100000.0, 'style_weight': 60000.0, 'tv_weight': 1.0, 'optimizer': 'lbfgs', 'model': 'vgg19', 'init_method': 'content', 'saving_freq': 50, 'content_images_dir': PosixPath('data/content-images'), 'style_images_dir': PosixPath('data/style-images'), 'output_img_dir': PosixPath('data/output-images'), 'images_path': PosixPath('data/test_style1/images'), 'gifs_path': PosixPath('data/test_style1/gifs'), 'img_format': (4, '.jpg')}
# 2021-12-10 19:44:43,749 [INFO] Starting training..
# 2021-12-10 19:44:44,318 [DEBUG] Using device cuda for training
# 2021-12-10 19:44:46,634 [DEBUG] Using vgg19 in the optimization procedure
# 2021-12-10 19:46:57,533 [DEBUG] Executed 1011 iterations
# 2021-12-10 19:46:57,533 [INFO] Training finished
# 2021-12-10 19:46:57,533 [INFO] Creating gif..
# 2021-12-10 19:47:06,202 [INFO] Copying data/output-images/combined_le_desespere_composition_viii/1000.jpg
# 2021-12-10 19:47:06,203 [INFO] Copying data/output-images/combined_le_desespere_composition_viii/out.gif
# 2021-12-10 19:47:06,203 [INFO] Copying to data/test_style1/gifs/gcomposition_viii.gif
# 2021-12-10 19:47:06,213 [INFO] Time elapsed: 142.4647490978241
#
# Processing content image: le_desespere.jpg
# Processing style: cows_red_green_yellow.jpg
# Saving image as cows_red_green_yellow
# 2021-12-10 19:47:07,580 [DEBUG] {'content_img_name': 'le_desespere.jpg', 'style_img_name': 'cows_red_green_yellow.jpg', 'output_img_name': 'cows_red_green_yellow', 'output_path': 'test_style1', 'height': 500, 'content_weight': 100000.0, 'style_weight': 60000.0, 'tv_weight': 1.0, 'optimizer': 'lbfgs', 'model': 'vgg19', 'init_method': 'content', 'saving_freq': 50, 'content_images_dir': PosixPath('data/content-images'), 'style_images_dir': PosixPath('data/style-images'), 'output_img_dir': PosixPath('data/output-images'), 'images_path': PosixPath('data/test_style1/images'), 'gifs_path': PosixPath('data/test_style1/gifs'), 'img_format': (4, '.jpg')}
# 2021-12-10 19:47:07,580 [INFO] Starting training..
# 2021-12-10 19:47:08,147 [DEBUG] Using device cuda for training
# 2021-12-10 19:47:10,456 [DEBUG] Using vgg19 in the optimization procedure
# 2021-12-10 19:49:23,327 [DEBUG] Executed 1022 iterations
# 2021-12-10 19:49:23,327 [INFO] Training finished
# 2021-12-10 19:49:23,328 [INFO] Creating gif..
# 2021-12-10 19:49:32,914 [INFO] Copying data/output-images/combined_le_desespere_cows_red_green_yellow/1000.jpg
# 2021-12-10 19:49:32,914 [INFO] Copying data/output-images/combined_le_desespere_cows_red_green_yellow/out.gif
# 2021-12-10 19:49:32,914 [INFO] Copying to data/test_style1/gifs/gcows_red_green_yellow.gif
# 2021-12-10 19:49:32,923 [INFO] Time elapsed: 145.34333539009094
#
# Processing content image: le_desespere.jpg
# Processing style: crows.jpg
# Saving image as crows
# 2021-12-10 19:49:34,278 [DEBUG] {'content_img_name': 'le_desespere.jpg', 'style_img_name': 'crows.jpg', 'output_img_name': 'crows', 'output_path': 'test_style1', 'height': 500, 'content_weight': 100000.0, 'style_weight': 60000.0, 'tv_weight': 1.0, 'optimizer': 'lbfgs', 'model': 'vgg19', 'init_method': 'content', 'saving_freq': 50, 'content_images_dir': PosixPath('data/content-images'), 'style_images_dir': PosixPath('data/style-images'), 'output_img_dir': PosixPath('data/output-images'), 'images_path': PosixPath('data/test_style1/images'), 'gifs_path': PosixPath('data/test_style1/gifs'), 'img_format': (4, '.jpg')}
# 2021-12-10 19:49:34,278 [INFO] Starting training..
# 2021-12-10 19:49:34,846 [DEBUG] Using device cuda for training
# 2021-12-10 19:49:37,179 [DEBUG] Using vgg19 in the optimization procedure
# 2021-12-10 19:51:48,578 [DEBUG] Executed 1017 iterations
# 2021-12-10 19:51:48,578 [INFO] Training finished
# 2021-12-10 19:51:48,579 [INFO] Creating gif..
# 2021-12-10 19:51:58,662 [INFO] Copying data/output-images/combined_le_desespere_crows/1000.jpg
# 2021-12-10 19:51:58,662 [INFO] Copying data/output-images/combined_le_desespere_crows/out.gif
# 2021-12-10 19:51:58,662 [INFO] Copying to data/test_style1/gifs/gcrows.gif
# 2021-12-10 19:51:58,672 [INFO] Time elapsed: 144.3951268196106
#
# Processing content image: le_desespere.jpg
# Processing style: dance_hall_bellevue.jpg
# Saving image as dance_hall_bellevue
# 2021-12-10 19:52:00,046 [DEBUG] {'content_img_name': 'le_desespere.jpg', 'style_img_name': 'dance_hall_bellevue.jpg', 'output_img_name': 'dance_hall_bellevue', 'output_path': 'test_style1', 'height': 500, 'content_weight': 100000.0, 'style_weight': 60000.0, 'tv_weight': 1.0, 'optimizer': 'lbfgs', 'model': 'vgg19', 'init_method': 'content', 'saving_freq': 50, 'content_images_dir': PosixPath('data/content-images'), 'style_images_dir': PosixPath('data/style-images'), 'output_img_dir': PosixPath('data/output-images'), 'images_path': PosixPath('data/test_style1/images'), 'gifs_path': PosixPath('data/test_style1/gifs'), 'img_format': (4, '.jpg')}
# 2021-12-10 19:52:00,046 [INFO] Starting training..
# 2021-12-10 19:52:00,617 [DEBUG] Using device cuda for training
# 2021-12-10 19:52:02,909 [DEBUG] Using vgg19 in the optimization procedure
# 2021-12-10 19:54:15,293 [DEBUG] Executed 1015 iterations
# 2021-12-10 19:54:15,293 [INFO] Training finished
# 2021-12-10 19:54:15,293 [INFO] Creating gif..
# 2021-12-10 19:54:24,902 [INFO] Copying data/output-images/combined_le_desespere_dance_hall_bellevue/1000.jpg
# 2021-12-10 19:54:24,903 [INFO] Copying data/output-images/combined_le_desespere_dance_hall_bellevue/out.gif
# 2021-12-10 19:54:24,903 [INFO] Copying to data/test_style1/gifs/gdance_hall_bellevue.gif
# 2021-12-10 19:54:24,912 [INFO] Time elapsed: 144.86676812171936
#
# Processing content image: le_desespere.jpg
# Processing style: death_and_life.jpg
# Saving image as death_and_life
# 2021-12-10 19:54:26,277 [DEBUG] {'content_img_name': 'le_desespere.jpg', 'style_img_name': 'death_and_life.jpg', 'output_img_name': 'death_and_life', 'output_path': 'test_style1', 'height': 500, 'content_weight': 100000.0, 'style_weight': 60000.0, 'tv_weight': 1.0, 'optimizer': 'lbfgs', 'model': 'vgg19', 'init_method': 'content', 'saving_freq': 50, 'content_images_dir': PosixPath('data/content-images'), 'style_images_dir': PosixPath('data/style-images'), 'output_img_dir': PosixPath('data/output-images'), 'images_path': PosixPath('data/test_style1/images'), 'gifs_path': PosixPath('data/test_style1/gifs'), 'img_format': (4, '.jpg')}
# 2021-12-10 19:54:26,278 [INFO] Starting training..
# 2021-12-10 19:54:26,845 [DEBUG] Using device cuda for training
# 2021-12-10 19:54:29,170 [DEBUG] Using vgg19 in the optimization procedure
# 2021-12-10 19:56:39,735 [DEBUG] Executed 1010 iterations
# 2021-12-10 19:56:39,735 [INFO] Training finished
# 2021-12-10 19:56:39,735 [INFO] Creating gif..
# 2021-12-10 19:56:48,992 [INFO] Copying data/output-images/combined_le_desespere_death_and_life/1000.jpg
# 2021-12-10 19:56:48,993 [INFO] Copying data/output-images/combined_le_desespere_death_and_life/out.gif
# 2021-12-10 19:56:48,993 [INFO] Copying to data/test_style1/gifs/gdeath_and_life.gif
# 2021-12-10 19:56:49,003 [INFO] Time elapsed: 142.72642636299133
#
# Processing content image: le_desespere.jpg
# Processing style: decoration_tuileries.jpg
# Saving image as decoration_tuileries
# 2021-12-10 19:56:50,379 [DEBUG] {'content_img_name': 'le_desespere.jpg', 'style_img_name': 'decoration_tuileries.jpg', 'output_img_name': 'decoration_tuileries', 'output_path': 'test_style1', 'height': 500, 'content_weight': 100000.0, 'style_weight': 60000.0, 'tv_weight': 1.0, 'optimizer': 'lbfgs', 'model': 'vgg19', 'init_method': 'content', 'saving_freq': 50, 'content_images_dir': PosixPath('data/content-images'), 'style_images_dir': PosixPath('data/style-images'), 'output_img_dir': PosixPath('data/output-images'), 'images_path': PosixPath('data/test_style1/images'), 'gifs_path': PosixPath('data/test_style1/gifs'), 'img_format': (4, '.jpg')}
# 2021-12-10 19:56:50,380 [INFO] Starting training..
# 2021-12-10 19:56:50,949 [DEBUG] Using device cuda for training
# 2021-12-10 19:56:53,239 [DEBUG] Using vgg19 in the optimization procedure
# 2021-12-10 19:59:05,296 [DEBUG] Executed 1009 iterations
# 2021-12-10 19:59:05,296 [INFO] Training finished
# 2021-12-10 19:59:05,297 [INFO] Creating gif..
# 2021-12-10 19:59:14,611 [INFO] Copying data/output-images/combined_le_desespere_decoration_tuileries/1000.jpg
# 2021-12-10 19:59:14,612 [INFO] Copying data/output-images/combined_le_desespere_decoration_tuileries/out.gif
# 2021-12-10 19:59:14,612 [INFO] Copying to data/test_style1/gifs/gdecoration_tuileries.gif
# 2021-12-10 19:59:14,620 [INFO] Time elapsed: 144.2414047718048
#
# Processing content image: le_desespere.jpg
# Processing style: der_geteckte_tisch.jpg
# Saving image as der_geteckte_tisch
# 2021-12-10 19:59:16,083 [DEBUG] {'content_img_name': 'le_desespere.jpg', 'style_img_name': 'der_geteckte_tisch.jpg', 'output_img_name': 'der_geteckte_tisch', 'output_path': 'test_style1', 'height': 500, 'content_weight': 100000.0, 'style_weight': 60000.0, 'tv_weight': 1.0, 'optimizer': 'lbfgs', 'model': 'vgg19', 'init_method': 'content', 'saving_freq': 50, 'content_images_dir': PosixPath('data/content-images'), 'style_images_dir': PosixPath('data/style-images'), 'output_img_dir': PosixPath('data/output-images'), 'images_path': PosixPath('data/test_style1/images'), 'gifs_path': PosixPath('data/test_style1/gifs'), 'img_format': (4, '.jpg')}
# 2021-12-10 19:59:16,084 [INFO] Starting training..
# 2021-12-10 19:59:16,649 [DEBUG] Using device cuda for training
# 2021-12-10 19:59:19,005 [DEBUG] Using vgg19 in the optimization procedure
# 2021-12-10 20:01:30,030 [DEBUG] Executed 1014 iterations
# 2021-12-10 20:01:30,030 [INFO] Training finished
# 2021-12-10 20:01:30,030 [INFO] Creating gif..
# 2021-12-10 20:01:39,783 [INFO] Copying data/output-images/combined_le_desespere_der_geteckte_tisch/1000.jpg
# 2021-12-10 20:01:39,784 [INFO] Copying data/output-images/combined_le_desespere_der_geteckte_tisch/out.gif
# 2021-12-10 20:01:39,784 [INFO] Copying to data/test_style1/gifs/gder_geteckte_tisch.gif
# 2021-12-10 20:01:39,795 [INFO] Time elapsed: 143.71204829216003
#
# Processing content image: le_desespere.jpg
# Processing style: edtaonisl.jpg
# Saving image as edtaonisl
# 2021-12-10 20:01:41,156 [DEBUG] {'content_img_name': 'le_desespere.jpg', 'style_img_name': 'edtaonisl.jpg', 'output_img_name': 'edtaonisl', 'output_path': 'test_style1', 'height': 500, 'content_weight': 100000.0, 'style_weight': 60000.0, 'tv_weight': 1.0, 'optimizer': 'lbfgs', 'model': 'vgg19', 'init_method': 'content', 'saving_freq': 50, 'content_images_dir': PosixPath('data/content-images'), 'style_images_dir': PosixPath('data/style-images'), 'output_img_dir': PosixPath('data/output-images'), 'images_path': PosixPath('data/test_style1/images'), 'gifs_path': PosixPath('data/test_style1/gifs'), 'img_format': (4, '.jpg')}
# 2021-12-10 20:01:41,157 [INFO] Starting training..
# 2021-12-10 20:01:41,717 [DEBUG] Using device cuda for training
# 2021-12-10 20:01:44,010 [DEBUG] Using vgg19 in the optimization procedure
# 2021-12-10 20:03:56,777 [DEBUG] Executed 1013 iterations
# 2021-12-10 20:03:56,777 [INFO] Training finished
# 2021-12-10 20:03:56,777 [INFO] Creating gif..
# 2021-12-10 20:04:06,440 [INFO] Copying data/output-images/combined_le_desespere_edtaonisl/1000.jpg
# 2021-12-10 20:04:06,440 [INFO] Copying data/output-images/combined_le_desespere_edtaonisl/out.gif
# 2021-12-10 20:04:06,441 [INFO] Copying to data/test_style1/gifs/gedtaonisl.gif
# 2021-12-10 20:04:06,449 [INFO] Time elapsed: 145.2937045097351
#
# Processing content image: le_desespere.jpg
# Processing style: elasticity.jpg
# Saving image as elasticity
# 2021-12-10 20:04:07,818 [DEBUG] {'content_img_name': 'le_desespere.jpg', 'style_img_name': 'elasticity.jpg', 'output_img_name': 'elasticity', 'output_path': 'test_style1', 'height': 500, 'content_weight': 100000.0, 'style_weight': 60000.0, 'tv_weight': 1.0, 'optimizer': 'lbfgs', 'model': 'vgg19', 'init_method': 'content', 'saving_freq': 50, 'content_images_dir': PosixPath('data/content-images'), 'style_images_dir': PosixPath('data/style-images'), 'output_img_dir': PosixPath('data/output-images'), 'images_path': PosixPath('data/test_style1/images'), 'gifs_path': PosixPath('data/test_style1/gifs'), 'img_format': (4, '.jpg')}
# 2021-12-10 20:04:07,818 [INFO] Starting training..
# 2021-12-10 20:04:08,386 [DEBUG] Using device cuda for training
# 2021-12-10 20:04:10,691 [DEBUG] Using vgg19 in the optimization procedure
# 2021-12-10 20:06:21,225 [DEBUG] Executed 1012 iterations
# 2021-12-10 20:06:21,225 [INFO] Training finished
# 2021-12-10 20:06:21,225 [INFO] Creating gif..
# 2021-12-10 20:06:31,092 [INFO] Copying data/output-images/combined_le_desespere_elasticity/1000.jpg
# 2021-12-10 20:06:31,092 [INFO] Copying data/output-images/combined_le_desespere_elasticity/out.gif
# 2021-12-10 20:06:31,092 [INFO] Copying to data/test_style1/gifs/gelasticity.gif
# 2021-12-10 20:06:31,103 [INFO] Time elapsed: 143.28508281707764
#
# Processing content image: le_desespere.jpg
# Processing style: flowers.jpg
# Saving image as flowers
# 2021-12-10 20:06:32,474 [DEBUG] {'content_img_name': 'le_desespere.jpg', 'style_img_name': 'flowers.jpg', 'output_img_name': 'flowers', 'output_path': 'test_style1', 'height': 500, 'content_weight': 100000.0, 'style_weight': 60000.0, 'tv_weight': 1.0, 'optimizer': 'lbfgs', 'model': 'vgg19', 'init_method': 'content', 'saving_freq': 50, 'content_images_dir': PosixPath('data/content-images'), 'style_images_dir': PosixPath('data/style-images'), 'output_img_dir': PosixPath('data/output-images'), 'images_path': PosixPath('data/test_style1/images'), 'gifs_path': PosixPath('data/test_style1/gifs'), 'img_format': (4, '.jpg')}
# 2021-12-10 20:06:32,475 [INFO] Starting training..
# 2021-12-10 20:06:33,037 [DEBUG] Using device cuda for training
# 2021-12-10 20:06:35,306 [DEBUG] Using vgg19 in the optimization procedure
# 2021-12-10 20:08:49,064 [DEBUG] Executed 1018 iterations
# 2021-12-10 20:08:49,064 [INFO] Training finished
# 2021-12-10 20:08:49,065 [INFO] Creating gif..
# 2021-12-10 20:08:58,406 [INFO] Copying data/output-images/combined_le_desespere_flowers/1000.jpg
# 2021-12-10 20:08:58,406 [INFO] Copying data/output-images/combined_le_desespere_flowers/out.gif
# 2021-12-10 20:08:58,406 [INFO] Copying to data/test_style1/gifs/gflowers.gif
# 2021-12-10 20:08:58,415 [INFO] Time elapsed: 145.9416162967682
#
# Processing content image: le_desespere.jpg
# Processing style: futuristic_composition.jpg
# Saving image as futuristic_composition
# 2021-12-10 20:08:59,778 [DEBUG] {'content_img_name': 'le_desespere.jpg', 'style_img_name': 'futuristic_composition.jpg', 'output_img_name': 'futuristic_composition', 'output_path': 'test_style1', 'height': 500, 'content_weight': 100000.0, 'style_weight': 60000.0, 'tv_weight': 1.0, 'optimizer': 'lbfgs', 'model': 'vgg19', 'init_method': 'content', 'saving_freq': 50, 'content_images_dir': PosixPath('data/content-images'), 'style_images_dir': PosixPath('data/style-images'), 'output_img_dir': PosixPath('data/output-images'), 'images_path': PosixPath('data/test_style1/images'), 'gifs_path': PosixPath('data/test_style1/gifs'), 'img_format': (4, '.jpg')}
# 2021-12-10 20:08:59,778 [INFO] Starting training..
# 2021-12-10 20:09:00,345 [DEBUG] Using device cuda for training
# 2021-12-10 20:09:02,620 [DEBUG] Using vgg19 in the optimization procedure
# 2021-12-10 20:11:13,902 [DEBUG] Executed 1021 iterations
# 2021-12-10 20:11:13,902 [INFO] Training finished
# 2021-12-10 20:11:13,903 [INFO] Creating gif..
# 2021-12-10 20:11:23,219 [INFO] Copying data/output-images/combined_le_desespere_futuristic_composition/1000.jpg
# 2021-12-10 20:11:23,220 [INFO] Copying data/output-images/combined_le_desespere_futuristic_composition/out.gif
# 2021-12-10 20:11:23,220 [INFO] Copying to data/test_style1/gifs/gfuturistic_composition.gif
# 2021-12-10 20:11:23,228 [INFO] Time elapsed: 143.4510054588318
#
# Processing content image: le_desespere.jpg
# Processing style: grainstacks.jpg
# Saving image as grainstacks
# 2021-12-10 20:11:24,585 [DEBUG] {'content_img_name': 'le_desespere.jpg', 'style_img_name': 'grainstacks.jpg', 'output_img_name': 'grainstacks', 'output_path': 'test_style1', 'height': 500, 'content_weight': 100000.0, 'style_weight': 60000.0, 'tv_weight': 1.0, 'optimizer': 'lbfgs', 'model': 'vgg19', 'init_method': 'content', 'saving_freq': 50, 'content_images_dir': PosixPath('data/content-images'), 'style_images_dir': PosixPath('data/style-images'), 'output_img_dir': PosixPath('data/output-images'), 'images_path': PosixPath('data/test_style1/images'), 'gifs_path': PosixPath('data/test_style1/gifs'), 'img_format': (4, '.jpg')}
# 2021-12-10 20:11:24,586 [INFO] Starting training..
# 2021-12-10 20:11:25,157 [DEBUG] Using device cuda for training
# 2021-12-10 20:11:27,477 [DEBUG] Using vgg19 in the optimization procedure
# 2021-12-10 20:13:43,601 [DEBUG] Executed 1018 iterations
# 2021-12-10 20:13:43,602 [INFO] Training finished
# 2021-12-10 20:13:43,602 [INFO] Creating gif..
# 2021-12-10 20:13:53,182 [INFO] Copying data/output-images/combined_le_desespere_grainstacks/1000.jpg
# 2021-12-10 20:13:53,183 [INFO] Copying data/output-images/combined_le_desespere_grainstacks/out.gif
# 2021-12-10 20:13:53,183 [INFO] Copying to data/test_style1/gifs/ggrainstacks.gif
# 2021-12-10 20:13:53,193 [INFO] Time elapsed: 148.60773229599
#
# Processing content image: le_desespere.jpg
# Processing style: great_wave.jpg
# Saving image as great_wave
# 2021-12-10 20:13:54,690 [DEBUG] {'content_img_name': 'le_desespere.jpg', 'style_img_name': 'great_wave.jpg', 'output_img_name': 'great_wave', 'output_path': 'test_style1', 'height': 500, 'content_weight': 100000.0, 'style_weight': 60000.0, 'tv_weight': 1.0, 'optimizer': 'lbfgs', 'model': 'vgg19', 'init_method': 'content', 'saving_freq': 50, 'content_images_dir': PosixPath('data/content-images'), 'style_images_dir': PosixPath('data/style-images'), 'output_img_dir': PosixPath('data/output-images'), 'images_path': PosixPath('data/test_style1/images'), 'gifs_path': PosixPath('data/test_style1/gifs'), 'img_format': (4, '.jpg')}
# 2021-12-10 20:13:54,691 [INFO] Starting training..
# 2021-12-10 20:13:55,257 [DEBUG] Using device cuda for training
# 2021-12-10 20:13:57,577 [DEBUG] Using vgg19 in the optimization procedure
# 2021-12-10 20:16:17,650 [DEBUG] Executed 1017 iterations
# 2021-12-10 20:16:17,650 [INFO] Training finished
# 2021-12-10 20:16:17,651 [INFO] Creating gif..
# 2021-12-10 20:16:26,591 [INFO] Copying data/output-images/combined_le_desespere_great_wave/1000.jpg
# 2021-12-10 20:16:26,591 [INFO] Copying data/output-images/combined_le_desespere_great_wave/out.gif
# 2021-12-10 20:16:26,591 [INFO] Copying to data/test_style1/gifs/ggreat_wave.gif
# 2021-12-10 20:16:26,602 [INFO] Time elapsed: 151.9119963645935
#
# Processing content image: le_desespere.jpg
# Processing style: guernica.jpg
# Saving image as guernica
# 2021-12-10 20:16:27,987 [DEBUG] {'content_img_name': 'le_desespere.jpg', 'style_img_name': 'guernica.jpg', 'output_img_name': 'guernica', 'output_path': 'test_style1', 'height': 500, 'content_weight': 100000.0, 'style_weight': 60000.0, 'tv_weight': 1.0, 'optimizer': 'lbfgs', 'model': 'vgg19', 'init_method': 'content', 'saving_freq': 50, 'content_images_dir': PosixPath('data/content-images'), 'style_images_dir': PosixPath('data/style-images'), 'output_img_dir': PosixPath('data/output-images'), 'images_path': PosixPath('data/test_style1/images'), 'gifs_path': PosixPath('data/test_style1/gifs'), 'img_format': (4, '.jpg')}
# 2021-12-10 20:16:27,987 [INFO] Starting training..
# 2021-12-10 20:16:28,557 [DEBUG] Using device cuda for training
# 2021-12-10 20:16:30,943 [DEBUG] Using vgg19 in the optimization procedure
# 2021-12-10 20:18:49,940 [DEBUG] Executed 1031 iterations
# 2021-12-10 20:18:49,940 [INFO] Training finished
# 2021-12-10 20:18:49,940 [INFO] Creating gif..
# 2021-12-10 20:18:57,226 [INFO] Copying data/output-images/combined_le_desespere_guernica/1000.jpg
# 2021-12-10 20:18:57,226 [INFO] Copying data/output-images/combined_le_desespere_guernica/out.gif
# 2021-12-10 20:18:57,226 [INFO] Copying to data/test_style1/gifs/gguernica.gif
# 2021-12-10 20:18:57,236 [INFO] Time elapsed: 149.2504153251648
#
# Processing content image: le_desespere.jpg
# Processing style: houses_at_auvers.jpg
# Saving image as houses_at_auvers
# 2021-12-10 20:18:58,628 [DEBUG] {'content_img_name': 'le_desespere.jpg', 'style_img_name': 'houses_at_auvers.jpg', 'output_img_name': 'houses_at_auvers', 'output_path': 'test_style1', 'height': 500, 'content_weight': 100000.0, 'style_weight': 60000.0, 'tv_weight': 1.0, 'optimizer': 'lbfgs', 'model': 'vgg19', 'init_method': 'content', 'saving_freq': 50, 'content_images_dir': PosixPath('data/content-images'), 'style_images_dir': PosixPath('data/style-images'), 'output_img_dir': PosixPath('data/output-images'), 'images_path': PosixPath('data/test_style1/images'), 'gifs_path': PosixPath('data/test_style1/gifs'), 'img_format': (4, '.jpg')}
# 2021-12-10 20:18:58,628 [INFO] Starting training..
# 2021-12-10 20:18:59,198 [DEBUG] Using device cuda for training
# 2021-12-10 20:19:01,500 [DEBUG] Using vgg19 in the optimization procedure
# 2021-12-10 20:21:12,030 [DEBUG] Executed 1013 iterations
# 2021-12-10 20:21:12,030 [INFO] Training finished
# 2021-12-10 20:21:12,031 [INFO] Creating gif..
# 2021-12-10 20:21:21,781 [INFO] Copying data/output-images/combined_le_desespere_houses_at_auvers/1000.jpg
# 2021-12-10 20:21:21,782 [INFO] Copying data/output-images/combined_le_desespere_houses_at_auvers/out.gif
# 2021-12-10 20:21:21,782 [INFO] Copying to data/test_style1/gifs/ghouses_at_auvers.gif
# 2021-12-10 20:21:21,792 [INFO] Time elapsed: 143.16495323181152
#
# Processing content image: le_desespere.jpg
# Processing style: improvisation_6_(afrikanisches).jpg
# Saving image as improvisation_6_(afrikanisches)
# /usr/bin/sh: 1: Syntax error: "(" unexpected
#
# Processing content image: le_desespere.jpg
# Processing style: in_the_rain.jpg
# Saving image as in_the_rain
# 2021-12-10 20:21:23,304 [DEBUG] {'content_img_name': 'le_desespere.jpg', 'style_img_name': 'in_the_rain.jpg', 'output_img_name': 'in_the_rain', 'output_path': 'test_style1', 'height': 500, 'content_weight': 100000.0, 'style_weight': 60000.0, 'tv_weight': 1.0, 'optimizer': 'lbfgs', 'model': 'vgg19', 'init_method': 'content', 'saving_freq': 50, 'content_images_dir': PosixPath('data/content-images'), 'style_images_dir': PosixPath('data/style-images'), 'output_img_dir': PosixPath('data/output-images'), 'images_path': PosixPath('data/test_style1/images'), 'gifs_path': PosixPath('data/test_style1/gifs'), 'img_format': (4, '.jpg')}
# 2021-12-10 20:21:23,304 [INFO] Starting training..
# 2021-12-10 20:21:23,867 [DEBUG] Using device cuda for training
# 2021-12-10 20:21:26,192 [DEBUG] Using vgg19 in the optimization procedure
# 2021-12-10 20:23:41,293 [DEBUG] Executed 1012 iterations
# 2021-12-10 20:23:41,293 [INFO] Training finished
# 2021-12-10 20:23:41,294 [INFO] Creating gif..
# 2021-12-10 20:23:49,737 [INFO] Copying data/output-images/combined_le_desespere_in_the_rain/1000.jpg
# 2021-12-10 20:23:49,738 [INFO] Copying data/output-images/combined_le_desespere_in_the_rain/out.gif
# 2021-12-10 20:23:49,738 [INFO] Copying to data/test_style1/gifs/gin_the_rain.gif
# 2021-12-10 20:23:49,748 [INFO] Time elapsed: 146.44476413726807
#
# Processing content image: le_desespere.jpg
# Processing style: interieur_mit_zwei_maedchen_anagoria.jfif
# Saving image as interieur_mit_zwei_maedchen_anagoria
# 2021-12-10 20:23:51,117 [DEBUG] {'content_img_name': 'le_desespere.jpg', 'style_img_name': 'interieur_mit_zwei_maedchen_anagoria.jfif', 'output_img_name': 'interieur_mit_zwei_maedchen_anagoria', 'output_path': 'test_style1', 'height': 500, 'content_weight': 100000.0, 'style_weight': 60000.0, 'tv_weight': 1.0, 'optimizer': 'lbfgs', 'model': 'vgg19', 'init_method': 'content', 'saving_freq': 50, 'content_images_dir': PosixPath('data/content-images'), 'style_images_dir': PosixPath('data/style-images'), 'output_img_dir': PosixPath('data/output-images'), 'images_path': PosixPath('data/test_style1/images'), 'gifs_path': PosixPath('data/test_style1/gifs'), 'img_format': (4, '.jpg')}
# 2021-12-10 20:23:51,117 [INFO] Starting training..
# 2021-12-10 20:23:51,688 [DEBUG] Using device cuda for training
# 2021-12-10 20:23:53,975 [DEBUG] Using vgg19 in the optimization procedure
# 2021-12-10 20:26:14,571 [DEBUG] Executed 1021 iterations
# 2021-12-10 20:26:14,571 [INFO] Training finished
# 2021-12-10 20:26:14,571 [INFO] Creating gif..
# 2021-12-10 20:26:23,745 [INFO] Copying data/output-images/combined_le_desespere_interieur_mit_zwei_maedchen_anagoria/1000.jpg
# 2021-12-10 20:26:23,746 [INFO] Copying data/output-images/combined_le_desespere_interieur_mit_zwei_maedchen_anagoria/out.gif
# 2021-12-10 20:26:23,746 [INFO] Copying to data/test_style1/gifs/ginterieur_mit_zwei_maedchen_anagoria.gif
# 2021-12-10 20:26:23,754 [INFO] Time elapsed: 152.63794946670532
#
# Processing content image: le_desespere.jpg
# Processing style: l_homme_a_femmes.jpg
# Saving image as l_homme_a_femmes
# 2021-12-10 20:26:25,121 [DEBUG] {'content_img_name': 'le_desespere.jpg', 'style_img_name': 'l_homme_a_femmes.jpg', 'output_img_name': 'l_homme_a_femmes', 'output_path': 'test_style1', 'height': 500, 'content_weight': 100000.0, 'style_weight': 60000.0, 'tv_weight': 1.0, 'optimizer': 'lbfgs', 'model': 'vgg19', 'init_method': 'content', 'saving_freq': 50, 'content_images_dir': PosixPath('data/content-images'), 'style_images_dir': PosixPath('data/style-images'), 'output_img_dir': PosixPath('data/output-images'), 'images_path': PosixPath('data/test_style1/images'), 'gifs_path': PosixPath('data/test_style1/gifs'), 'img_format': (4, '.jpg')}
# 2021-12-10 20:26:25,121 [INFO] Starting training..
# 2021-12-10 20:26:25,686 [DEBUG] Using device cuda for training
# 2021-12-10 20:26:28,014 [DEBUG] Using vgg19 in the optimization procedure
# 2021-12-10 20:28:45,184 [DEBUG] Executed 1019 iterations
# 2021-12-10 20:28:45,184 [INFO] Training finished
# 2021-12-10 20:28:45,184 [INFO] Creating gif..
# 2021-12-10 20:28:53,981 [INFO] Copying data/output-images/combined_le_desespere_l_homme_a_femmes/1000.jpg
# 2021-12-10 20:28:53,982 [INFO] Copying data/output-images/combined_le_desespere_l_homme_a_femmes/out.gif
# 2021-12-10 20:28:53,982 [INFO] Copying to data/test_style1/gifs/gl_homme_a_femmes.gif
# 2021-12-10 20:28:53,994 [INFO] Time elapsed: 148.8737862110138
#
# Processing content image: le_desespere.jpg
# Processing style: les_demoiselles_davignon.jpg
# Saving image as les_demoiselles_davignon
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 263, in <module>
#     main(optimization_config)
# TypeError: main() takes 0 positional arguments but 1 was given
#
# Processing content image: le_desespere.jpg
# Processing style: marilyn_monroe.jpg
# Saving image as marilyn_monroe
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 263, in <module>
#     main(optimization_config)
# TypeError: main() takes 0 positional arguments but 1 was given
#
# Processing content image: le_desespere.jpg
# Processing style: mendrisiotto_obino.jpeg
# Saving image as mendrisiotto_obino
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 263, in <module>
#     main(optimization_config)
# TypeError: main() takes 0 positional arguments but 1 was given
#
# Processing content image: le_desespere.jpg
# Processing style: montagne_sainte_victoire.jpg
# Saving image as montagne_sainte_victoire
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 263, in <module>
#     main(optimization_config)
# TypeError: main() takes 0 positional arguments but 1 was given
#
# Processing content image: le_desespere.jpg
# Processing style: mosaic.jpeg
# Saving image as mosaic
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 263, in <module>
#     main(optimization_config)
# TypeError: main() takes 0 positional arguments but 1 was given
#
# Processing content image: le_desespere.jpg
# Processing style: osterreichische_galerie_belvedere.jpg
# Saving image as osterreichische_galerie_belvedere
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 263, in <module>
#     main(optimization_config)
# TypeError: main() takes 0 positional arguments but 1 was given
#
# Processing content image: le_desespere.jpg
# Processing style: red_canna.png
# Saving image as red_canna
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 263, in <module>
#     main(optimization_config)
# TypeError: main() takes 0 positional arguments but 1 was given
#
# Processing content image: le_desespere.jpg
# Processing style: rhone.jpg
# Saving image as rhone
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 263, in <module>
#     main(optimization_config)
# TypeError: main() takes 0 positional arguments but 1 was given
#
# Processing content image: le_desespere.jpg
# Processing style: sertig_valley_in_autumn.jpg
# Saving image as sertig_valley_in_autumn
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 263, in <module>
#     main(optimization_config)
# TypeError: main() takes 0 positional arguments but 1 was given
#
# Processing content image: le_desespere.jpg
# Processing style: squares_with_concentric_circles.jpg
# Saving image as squares_with_concentric_circles
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 263, in <module>
#     main(optimization_config)
# TypeError: main() takes 0 positional arguments but 1 was given
#
# Processing content image: le_desespere.jpg
# Processing style: street_berlin.jpg
# Saving image as street_berlin
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 263, in <module>
#     main(optimization_config)
# TypeError: main() takes 0 positional arguments but 1 was given
#
# Processing content image: le_desespere.jpg
# Processing style: the_circus.jpg
# Saving image as the_circus
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 263, in <module>
#     main(optimization_config)
# TypeError: main() takes 0 positional arguments but 1 was given
#
# Processing content image: le_desespere.jpg
# Processing style: the_knife_grinder.jpeg
# Saving image as the_knife_grinder
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 263, in <module>
#     main(optimization_config)
# TypeError: main() takes 0 positional arguments but 1 was given
#
# Processing content image: le_desespere.jpg
# Processing style: the_liver_is_the_cocks_comb.jpg
# Saving image as the_liver_is_the_cocks_comb
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 263, in <module>
#     main(optimization_config)
# TypeError: main() takes 0 positional arguments but 1 was given
#
# Processing content image: le_desespere.jpg
# Processing style: the_maiden.jpg
# Saving image as the_maiden
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 263, in <module>
#     main(optimization_config)
# TypeError: main() takes 0 positional arguments but 1 was given
#
# Processing content image: le_desespere.jpg
# Processing style: the_park.jpg
# Saving image as the_park
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 263, in <module>
#     main(optimization_config)
# TypeError: main() takes 0 positional arguments but 1 was given
#
# Processing content image: le_desespere.jpg
# Processing style: the_starry_night.jpg
# Saving image as the_starry_night
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 263, in <module>
#     main(optimization_config)
# TypeError: main() takes 0 positional arguments but 1 was given
#
# Processing content image: le_desespere.jpg
# Processing style: the_yellow_cow.jpg
# Saving image as the_yellow_cow
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 263, in <module>
#     main(optimization_config)
# TypeError: main() takes 0 positional arguments but 1 was given
#
# Processing content image: le_desespere.jpg
# Processing style: three_trees_autumn_effect.jpg
# Saving image as three_trees_autumn_effect
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 263, in <module>
#     main(optimization_config)
# TypeError: main() takes 0 positional arguments but 1 was given
#
# Processing content image: le_desespere.jpg
# Processing style: tour_eiffel.jpg
# Saving image as tour_eiffel
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 263, in <module>
#     main(optimization_config)
# TypeError: main() takes 0 positional arguments but 1 was given
#
# Processing content image: le_desespere.jpg
# Processing style: udnie.jpg
# Saving image as udnie
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 263, in <module>
#     main(optimization_config)
# TypeError: main() takes 0 positional arguments but 1 was given
#
# Processing content image: le_desespere.jpg
# Processing style: untitled_first_abstract_watercolor.jpg
# Saving image as untitled_first_abstract_watercolor
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 263, in <module>
#     main(optimization_config)
# TypeError: main() takes 0 positional arguments but 1 was given
#
# Processing content image: le_desespere.jpg
# Processing style: untitled_improvisation_III.jpg
# Saving image as untitled_improvisation_III
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 263, in <module>
#     main(optimization_config)
# TypeError: main() takes 0 positional arguments but 1 was given
#
# Processing content image: le_desespere.jpg
# Processing style: upward.jpg
# Saving image as upward
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 263, in <module>
#     main(optimization_config)
# TypeError: main() takes 0 positional arguments but 1 was given
#
# Processing content image: le_desespere.jpg
# Processing style: vertumnus.jpg
# Saving image as vertumnus
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 263, in <module>
#     main(optimization_config)
# TypeError: main() takes 0 positional arguments but 1 was given
#
# Processing content image: le_desespere.jpg
# Processing style: wall.jpg
# Saving image as wall
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 263, in <module>
#     main(optimization_config)
# TypeError: main() takes 0 positional arguments but 1 was given
#
# Processing content image: le_desespere.jpg
# Processing style: wasserschlangen_ii.jpeg
# Saving image as wasserschlangen_ii
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 263, in <module>
#     main(optimization_config)
# TypeError: main() takes 0 positional arguments but 1 was given
#
# Processing content image: le_desespere.jpg
# Processing style: wheat.jpg
# Saving image as wheat
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 263, in <module>
#     main(optimization_config)
# TypeError: main() takes 0 positional arguments but 1 was given
#
# Processing content image: le_desespere.jpg
# Processing style: yellow_accompaniment.jpg
# Saving image as yellow_accompaniment
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 263, in <module>
#     main(optimization_config)
# TypeError: main() takes 0 positional arguments but 1 was given
