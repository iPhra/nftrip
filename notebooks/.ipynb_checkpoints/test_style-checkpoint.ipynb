# %%
import os
os.chdir('../')

# %%
import pandas as pd
from pathlib import Path
from PIL import Image
import json
import random

# %%
root_path = Path('./data/')

# %%
style_df = pd.read_csv(root_path / 'metadata' / 'style.csv')

content_df = pd.read_csv(root_path / 'metadata' / 'content.csv')

# %%
content_df.head()
# Out:
#                                        Title                 Author  \
# 0                  Big Campbell Soup Can 19C            Andy Warhol
# 1                          Cats Named Sam IV            Andy Warhol
# 2                            Soup Can Tomato            Andy Warhol
# 3                          Virgin Annunciate   Antonello da Messina
# 4  Self-Portrait as the Allegory of Painting  Artemisia Gentileschi
#
#   Orientation   Resolution                       File_name Notes
# 0    Portrait    598 × 800  big_campbells_soup_can_19c.jpg   NaN
# 1    Portrait    500 × 765        cats_named_sam_iv_61.jpg   NaN
# 2    Portrait  1596 × 2000             soup_can_tomato.jpg   NaN
# 3    Portrait      552x720                  annunciate.jpg   NaN
# 4    Portrait     818x1080                   allegorie.jpg   NaN

# %%
style_df.head()
# Out:
#                                   Title              Author  Resolution  \
# 0                 Bed of Chrysanthemums        Claude Monet    688x1024
# 1                         Blue Mountain   Wassily Kandinsky    947x1024
# 2                         Cocina Alpina     Ludwig Kirchner   1025x1024
# 3  Composition with Red Blue and Yellow       Piet Mondrian   1010x1024
# 4                      Composition VIII  Vasilij Kandinskij  1090 × 755
#
#                                      File_name  Notes
# 0                    bed_of_chrysanthemums.jpg  Luigi
# 1                           blue_mountain.jfif  Luigi
# 2                            cocina_alpina.jpg  Luigi
# 3  composition_II_with_red_blue_and_yellow.jpg  Luigi
# 4                         composition_viii.jpg    NaN

# %%
content_path = root_path / 'content-images'
style_path = root_path / 'style-images'

# %%
content = content_df[content_df.Title=='Mona Lisa']
for j, style in style_df.iterrows():

    content_img_path = content_path / content['File_name']    
    style_img_path = style_path / style['File_name']
    output_name = f'test_style/{style["File_name"]}'

    print(f"Processing content image: {content['File_name']}")
    print(f"Processing style: {style['File_name']}")
    print(f"Saving image as {output_name}")
    
    try:
        # !python3 neural_style_transfer.py --content_img_name {content['File_name']} --style_img_name {style['File_name']} --output_img_name {output_name} --video {"False"}
    except:
        print(style['File_name'])
    
    print()
# Out:
# Processing content image: 35    mona_lisa.jpeg
# Name: File_name, dtype: object
# Processing style: bed_of_chrysanthemums.jpg
# Saving image as test_style/bed_of_chrysanthemums.jpg
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 1, in <module>
#     import utils.utils as utils
#   File "/Users/iphra/Projects/nftrip/utils/utils.py", line 1, in <module>
#     import cv2 as cv
# ModuleNotFoundError: No module named 'cv2'
# zsh:2: command not found: Name:
#
# Processing content image: 35    mona_lisa.jpeg
# Name: File_name, dtype: object
# Processing style: blue_mountain.jfif
# Saving image as test_style/blue_mountain.jfif
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 1, in <module>
#     import utils.utils as utils
#   File "/Users/iphra/Projects/nftrip/utils/utils.py", line 1, in <module>
#     import cv2 as cv
# ModuleNotFoundError: No module named 'cv2'
# zsh:2: command not found: Name:
#
# Processing content image: 35    mona_lisa.jpeg
# Name: File_name, dtype: object
# Processing style: cocina_alpina.jpg
# Saving image as test_style/cocina_alpina.jpg
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 1, in <module>
#     import utils.utils as utils
#   File "/Users/iphra/Projects/nftrip/utils/utils.py", line 1, in <module>
#     import cv2 as cv
# ModuleNotFoundError: No module named 'cv2'
# zsh:2: command not found: Name:
#
# Processing content image: 35    mona_lisa.jpeg
# Name: File_name, dtype: object
# Processing style: composition_II_with_red_blue_and_yellow.jpg
# Saving image as test_style/composition_II_with_red_blue_and_yellow.jpg
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 1, in <module>
#     import utils.utils as utils
#   File "/Users/iphra/Projects/nftrip/utils/utils.py", line 1, in <module>
#     import cv2 as cv
# ModuleNotFoundError: No module named 'cv2'
# zsh:2: command not found: Name:
#
# Processing content image: 35    mona_lisa.jpeg
# Name: File_name, dtype: object
# Processing style: composition_viii.jpg
# Saving image as test_style/composition_viii.jpg
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 1, in <module>
#     import utils.utils as utils
#   File "/Users/iphra/Projects/nftrip/utils/utils.py", line 1, in <module>
#     import cv2 as cv
# ModuleNotFoundError: No module named 'cv2'
# zsh:2: command not found: Name:
#
# Processing content image: 35    mona_lisa.jpeg
# Name: File_name, dtype: object
# Processing style: crows.jpg
# Saving image as test_style/crows.jpg
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 1, in <module>
#     import utils.utils as utils
#   File "/Users/iphra/Projects/nftrip/utils/utils.py", line 1, in <module>
#     import cv2 as cv
# ModuleNotFoundError: No module named 'cv2'
# zsh:2: command not found: Name:
#
# Processing content image: 35    mona_lisa.jpeg
# Name: File_name, dtype: object
# Processing style: dance_hall_bellevue.jpg
# Saving image as test_style/dance_hall_bellevue.jpg
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 1, in <module>
#     import utils.utils as utils
#   File "/Users/iphra/Projects/nftrip/utils/utils.py", line 1, in <module>
#     import cv2 as cv
# ModuleNotFoundError: No module named 'cv2'
# zsh:2: command not found: Name:
#
# Processing content image: 35    mona_lisa.jpeg
# Name: File_name, dtype: object
# Processing style: edtaonisl.jpg
# Saving image as test_style/edtaonisl.jpg
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 1, in <module>
#     import utils.utils as utils
#   File "/Users/iphra/Projects/nftrip/utils/utils.py", line 1, in <module>
#     import cv2 as cv
# ModuleNotFoundError: No module named 'cv2'
# zsh:2: command not found: Name:
#
# Processing content image: 35    mona_lisa.jpeg
# Name: File_name, dtype: object
# Processing style: elasticity.jpg
# Saving image as test_style/elasticity.jpg
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 1, in <module>
#     import utils.utils as utils
#   File "/Users/iphra/Projects/nftrip/utils/utils.py", line 1, in <module>
#     import cv2 as cv
# ModuleNotFoundError: No module named 'cv2'
# zsh:2: command not found: Name:
#
# Processing content image: 35    mona_lisa.jpeg
# Name: File_name, dtype: object
# Processing style: flowers.jpg
# Saving image as test_style/flowers.jpg
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 1, in <module>
#     import utils.utils as utils
#   File "/Users/iphra/Projects/nftrip/utils/utils.py", line 1, in <module>
#     import cv2 as cv
# ModuleNotFoundError: No module named 'cv2'
# zsh:2: command not found: Name:
#
# Processing content image: 35    mona_lisa.jpeg
# Name: File_name, dtype: object
# Processing style: futuristic_composition.jpg
# Saving image as test_style/futuristic_composition.jpg
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 1, in <module>
#     import utils.utils as utils
#   File "/Users/iphra/Projects/nftrip/utils/utils.py", line 1, in <module>
#     import cv2 as cv
# ModuleNotFoundError: No module named 'cv2'
# zsh:2: command not found: Name:
#
# Processing content image: 35    mona_lisa.jpeg
# Name: File_name, dtype: object
# Processing style: grainstacks.jpg
# Saving image as test_style/grainstacks.jpg
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 1, in <module>
#     import utils.utils as utils
#   File "/Users/iphra/Projects/nftrip/utils/utils.py", line 1, in <module>
#     import cv2 as cv
# ModuleNotFoundError: No module named 'cv2'
# zsh:2: command not found: Name:
#
# Processing content image: 35    mona_lisa.jpeg
# Name: File_name, dtype: object
# Processing style: great_wave.jpg
# Saving image as test_style/great_wave.jpg
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 1, in <module>
#     import utils.utils as utils
#   File "/Users/iphra/Projects/nftrip/utils/utils.py", line 1, in <module>
#     import cv2 as cv
# ModuleNotFoundError: No module named 'cv2'
# zsh:2: command not found: Name:
#
# Processing content image: 35    mona_lisa.jpeg
# Name: File_name, dtype: object
# Processing style: guernica.jpg
# Saving image as test_style/guernica.jpg
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 1, in <module>
#     import utils.utils as utils
#   File "/Users/iphra/Projects/nftrip/utils/utils.py", line 1, in <module>
#     import cv2 as cv
# ModuleNotFoundError: No module named 'cv2'
# zsh:2: command not found: Name:
#
# Processing content image: 35    mona_lisa.jpeg
# Name: File_name, dtype: object
# Processing style: houses_at_auvers.jpg
# Saving image as test_style/houses_at_auvers.jpg
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 1, in <module>
#     import utils.utils as utils
#   File "/Users/iphra/Projects/nftrip/utils/utils.py", line 1, in <module>
#     import cv2 as cv
# ModuleNotFoundError: No module named 'cv2'
# zsh:2: command not found: Name:
#
# Processing content image: 35    mona_lisa.jpeg
# Name: File_name, dtype: object
# Processing style: improvisation_6_(afrikanisches).jpg
# Saving image as test_style/improvisation_6_(afrikanisches).jpg
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 1, in <module>
#     import utils.utils as utils
#   File "/Users/iphra/Projects/nftrip/utils/utils.py", line 1, in <module>
#     import cv2 as cv
# ModuleNotFoundError: No module named 'cv2'
# zsh:2: no matches found: improvisation_6_(afrikanisches).jpg
#
# Processing content image: 35    mona_lisa.jpeg
# Name: File_name, dtype: object
# Processing style: interieur_mit_zwei_maedchen_anagoria.jpg
# Saving image as test_style/interieur_mit_zwei_maedchen_anagoria.jpg
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 1, in <module>
#     import utils.utils as utils
#   File "/Users/iphra/Projects/nftrip/utils/utils.py", line 1, in <module>
#     import cv2 as cv
# ModuleNotFoundError: No module named 'cv2'
# zsh:2: command not found: Name:
#
# Processing content image: 35    mona_lisa.jpeg
# Name: File_name, dtype: object
# Processing style: l_homme_a_femmes.jpg
# Saving image as test_style/l_homme_a_femmes.jpg
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 1, in <module>
#     import utils.utils as utils
#   File "/Users/iphra/Projects/nftrip/utils/utils.py", line 1, in <module>
#     import cv2 as cv
# ModuleNotFoundError: No module named 'cv2'
# zsh:2: command not found: Name:
#
# Processing content image: 35    mona_lisa.jpeg
# Name: File_name, dtype: object
# Processing style: les_demoiselles_davignon.jpg
# Saving image as test_style/les_demoiselles_davignon.jpg
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 1, in <module>
#     import utils.utils as utils
#   File "/Users/iphra/Projects/nftrip/utils/utils.py", line 1, in <module>
#     import cv2 as cv
# ModuleNotFoundError: No module named 'cv2'
# zsh:2: command not found: Name:
#
# Processing content image: 35    mona_lisa.jpeg
# Name: File_name, dtype: object
# Processing style: marilyn_monroe.jpg
# Saving image as test_style/marilyn_monroe.jpg
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 1, in <module>
#     import utils.utils as utils
#   File "/Users/iphra/Projects/nftrip/utils/utils.py", line 1, in <module>
#     import cv2 as cv
# ModuleNotFoundError: No module named 'cv2'
# zsh:2: command not found: Name:
#
# Processing content image: 35    mona_lisa.jpeg
# Name: File_name, dtype: object
# Processing style: montagne_sainte_victoire.jpg
# Saving image as test_style/montagne_sainte_victoire.jpg
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 1, in <module>
#     import utils.utils as utils
#   File "/Users/iphra/Projects/nftrip/utils/utils.py", line 1, in <module>
#     import cv2 as cv
# ModuleNotFoundError: No module named 'cv2'
# zsh:2: command not found: Name:
#
# Processing content image: 35    mona_lisa.jpeg
# Name: File_name, dtype: object
# Processing style: osterreichische_galerie_belvedere.jpg
# Saving image as test_style/osterreichische_galerie_belvedere.jpg
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 1, in <module>
#     import utils.utils as utils
#   File "/Users/iphra/Projects/nftrip/utils/utils.py", line 1, in <module>
#     import cv2 as cv
# ModuleNotFoundError: No module named 'cv2'
# zsh:2: command not found: Name:
#
# Processing content image: 35    mona_lisa.jpeg
# Name: File_name, dtype: object
# Processing style: red_canna.png
# Saving image as test_style/red_canna.png
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 1, in <module>
#     import utils.utils as utils
#   File "/Users/iphra/Projects/nftrip/utils/utils.py", line 1, in <module>
#     import cv2 as cv
# ModuleNotFoundError: No module named 'cv2'
# zsh:2: command not found: Name:
#
# Processing content image: 35    mona_lisa.jpeg
# Name: File_name, dtype: object
# Processing style: rhone.jpg
# Saving image as test_style/rhone.jpg
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 1, in <module>
#     import utils.utils as utils
#   File "/Users/iphra/Projects/nftrip/utils/utils.py", line 1, in <module>
#     import cv2 as cv
# ModuleNotFoundError: No module named 'cv2'
# zsh:2: command not found: Name:
#
# Processing content image: 35    mona_lisa.jpeg
# Name: File_name, dtype: object
# Processing style: sertig_valley_in_autumn.jpg
# Saving image as test_style/sertig_valley_in_autumn.jpg
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 1, in <module>
#     import utils.utils as utils
#   File "/Users/iphra/Projects/nftrip/utils/utils.py", line 1, in <module>
#     import cv2 as cv
# ModuleNotFoundError: No module named 'cv2'
# zsh:2: command not found: Name:
#
# Processing content image: 35    mona_lisa.jpeg
# Name: File_name, dtype: object
# Processing style: squares_with_concentric_circles.jpg
# Saving image as test_style/squares_with_concentric_circles.jpg
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 1, in <module>
#     import utils.utils as utils
#   File "/Users/iphra/Projects/nftrip/utils/utils.py", line 1, in <module>
#     import cv2 as cv
# ModuleNotFoundError: No module named 'cv2'
# zsh:2: command not found: Name:
#
# Processing content image: 35    mona_lisa.jpeg
# Name: File_name, dtype: object
# Processing style: street_berlin.jpg
# Saving image as test_style/street_berlin.jpg
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 1, in <module>
#     import utils.utils as utils
#   File "/Users/iphra/Projects/nftrip/utils/utils.py", line 1, in <module>
#     import cv2 as cv
# ModuleNotFoundError: No module named 'cv2'
# zsh:2: command not found: Name:
#
# Processing content image: 35    mona_lisa.jpeg
# Name: File_name, dtype: object
# Processing style: the_circus.jpg
# Saving image as test_style/the_circus.jpg
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 1, in <module>
#     import utils.utils as utils
#   File "/Users/iphra/Projects/nftrip/utils/utils.py", line 1, in <module>
#     import cv2 as cv
# ModuleNotFoundError: No module named 'cv2'
# zsh:2: command not found: Name:
#
# Processing content image: 35    mona_lisa.jpeg
# Name: File_name, dtype: object
# Processing style: the_liver_is_the_cocks_comb.jpg
# Saving image as test_style/the_liver_is_the_cocks_comb.jpg
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 1, in <module>
#     import utils.utils as utils
#   File "/Users/iphra/Projects/nftrip/utils/utils.py", line 1, in <module>
#     import cv2 as cv
# ModuleNotFoundError: No module named 'cv2'
# zsh:2: command not found: Name:
#
# Processing content image: 35    mona_lisa.jpeg
# Name: File_name, dtype: object
# Processing style: the_park.jpg
# Saving image as test_style/the_park.jpg
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 1, in <module>
#     import utils.utils as utils
#   File "/Users/iphra/Projects/nftrip/utils/utils.py", line 1, in <module>
#     import cv2 as cv
# ModuleNotFoundError: No module named 'cv2'
# zsh:2: command not found: Name:
#
# Processing content image: 35    mona_lisa.jpeg
# Name: File_name, dtype: object
# Processing style: the_starry_night.jpg
# Saving image as test_style/the_starry_night.jpg
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 1, in <module>
#     import utils.utils as utils
#   File "/Users/iphra/Projects/nftrip/utils/utils.py", line 1, in <module>
#     import cv2 as cv
# ModuleNotFoundError: No module named 'cv2'
# zsh:2: command not found: Name:
#
# Processing content image: 35    mona_lisa.jpeg
# Name: File_name, dtype: object
# Processing style: three_trees_autumn_effect.jpg
# Saving image as test_style/three_trees_autumn_effect.jpg
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 1, in <module>
#     import utils.utils as utils
#   File "/Users/iphra/Projects/nftrip/utils/utils.py", line 1, in <module>
#     import cv2 as cv
# ModuleNotFoundError: No module named 'cv2'
# zsh:2: command not found: Name:
#
# Processing content image: 35    mona_lisa.jpeg
# Name: File_name, dtype: object
# Processing style: tour_eiffel.jpg
# Saving image as test_style/tour_eiffel.jpg
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 1, in <module>
#     import utils.utils as utils
#   File "/Users/iphra/Projects/nftrip/utils/utils.py", line 1, in <module>
#     import cv2 as cv
# ModuleNotFoundError: No module named 'cv2'
# zsh:2: command not found: Name:
#
# Processing content image: 35    mona_lisa.jpeg
# Name: File_name, dtype: object
# Processing style: udnie.jpg
# Saving image as test_style/udnie.jpg
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 1, in <module>
#     import utils.utils as utils
#   File "/Users/iphra/Projects/nftrip/utils/utils.py", line 1, in <module>
#     import cv2 as cv
# ModuleNotFoundError: No module named 'cv2'
# zsh:2: command not found: Name:
#
# Processing content image: 35    mona_lisa.jpeg
# Name: File_name, dtype: object
# Processing style: untitled_first_abstract_watercolor.jpg
# Saving image as test_style/untitled_first_abstract_watercolor.jpg
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 1, in <module>
#     import utils.utils as utils
#   File "/Users/iphra/Projects/nftrip/utils/utils.py", line 1, in <module>
#     import cv2 as cv
# ModuleNotFoundError: No module named 'cv2'
# zsh:2: command not found: Name:
#
# Processing content image: 35    mona_lisa.jpeg
# Name: File_name, dtype: object
# Processing style: untitled_improvisation_III.jpg
# Saving image as test_style/untitled_improvisation_III.jpg
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 1, in <module>
#     import utils.utils as utils
#   File "/Users/iphra/Projects/nftrip/utils/utils.py", line 1, in <module>
#     import cv2 as cv
# ModuleNotFoundError: No module named 'cv2'
# zsh:2: command not found: Name:
#
# Processing content image: 35    mona_lisa.jpeg
# Name: File_name, dtype: object
# Processing style: upward.jpg
# Saving image as test_style/upward.jpg
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 1, in <module>
#     import utils.utils as utils
#   File "/Users/iphra/Projects/nftrip/utils/utils.py", line 1, in <module>
#     import cv2 as cv
# ModuleNotFoundError: No module named 'cv2'
# zsh:2: command not found: Name:
#
# Processing content image: 35    mona_lisa.jpeg
# Name: File_name, dtype: object
# Processing style: wall.jpg
# Saving image as test_style/wall.jpg
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 1, in <module>
#     import utils.utils as utils
#   File "/Users/iphra/Projects/nftrip/utils/utils.py", line 1, in <module>
#     import cv2 as cv
# ModuleNotFoundError: No module named 'cv2'
# zsh:2: command not found: Name:
#
# Processing content image: 35    mona_lisa.jpeg
# Name: File_name, dtype: object
# Processing style: wheat.jpg
# Saving image as test_style/wheat.jpg
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 1, in <module>
#     import utils.utils as utils
#   File "/Users/iphra/Projects/nftrip/utils/utils.py", line 1, in <module>
#     import cv2 as cv
# ModuleNotFoundError: No module named 'cv2'
# zsh:2: command not found: Name:
#
# Processing content image: 35    mona_lisa.jpeg
# Name: File_name, dtype: object
# Processing style: yellow_accompaniment.jpg
# Saving image as test_style/yellow_accompaniment.jpg
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 1, in <module>
#     import utils.utils as utils
#   File "/Users/iphra/Projects/nftrip/utils/utils.py", line 1, in <module>
#     import cv2 as cv
# ModuleNotFoundError: No module named 'cv2'
# zsh:2: command not found: Name:
