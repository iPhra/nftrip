# %%
import os
os.chdir('../')

# %%
import pandas as pd
from pathlib import Path
from PIL import Image
import json
import random

# %%
root_path = Path('./data/')

# %%
style_df = pd.read_csv(root_path / 'metadata' / 'style.csv')

content_df = pd.read_csv(root_path / 'metadata' / 'content.csv')

# %%
content_df.head()
# Out:
#                                        Title                 Author  \
# 0                  Big Campbell Soup Can 19C            Andy Warhol
# 1                          Cats Named Sam IV            Andy Warhol
# 2                            Soup Can Tomato            Andy Warhol
# 3                          Virgin Annunciate   Antonello da Messina
# 4  Self-Portrait as the Allegory of Painting  Artemisia Gentileschi
#
#   Orientation   Resolution                       File_name Notes
# 0    Portrait    598 × 800  big_campbells_soup_can_19c.jpg   NaN
# 1    Portrait    500 × 765        cats_named_sam_iv_61.jpg   NaN
# 2    Portrait  1596 × 2000             soup_can_tomato.jpg   NaN
# 3    Portrait      552x720                  annunciate.jpg   NaN
# 4    Portrait     818x1080                   allegorie.jpg   NaN

# %%
style_df.head()
# Out:
#                           Title         Author   Resolution  \
# 0               Marilyin Monroe    Andy Warhol  2000 × 1992
# 1  The Liver Is the Cock's Comb  Arshile Gorky     1280x952
# 2                       Flowers      Ben Giles      512x512
# 3         Bed of Chrysanthemums   Claude Monet     688x1024
# 4                   Grainstacks   Claude Monet    1280x1010
#
#                          File_name  Notes
# 0               marilyn_monroe.jpg    NaN
# 1  the_liver_is_the_cocks_comb.jpg  Luigi
# 2                      flowers.jpg    NaN
# 3        bed_of_chrysanthemums.jpg  Luigi
# 4                  grainstacks.jpg  Luigi

# %%
content_path = root_path / 'content-images'
style_path = root_path / 'style-images'

# %%
style = style_df[style_df.Title=='The Starry Night'].iloc[0]
for j, content in content_df.iterrows():

    content_img_path = content_path / content['File_name']    
    style_img_path = style_path / style['File_name']
    output_name = f'{content["File_name"]}'.split('.')[0]

    print(f"Processing content image: {content['File_name']}")
    print(f"Processing style: {style['File_name']}")
    print(f"Saving image as {output_name}")
    
    try:
        # !python neural_style_transfer.py --content_img_name {content['File_name']} --style_img_name {style['File_name']} --output_img_name {output_name} --video {"False"} --output_path test_content1
    except:
        print(style['File_name'])
    
    print()
# Out:
# Processing content image: big_campbells_soup_can_19c.jpg
# Processing style: the_starry_night.jpg
# Saving image as big_campbells_soup_can_19c
# Using vgg19 in the optimization procedure.
# L-BFGS | iteration: 000, total loss=2725978832896.0000, content_loss=      0.0000, style loss=2725969440000.0000, tv loss=9560524.0000
# L-BFGS | iteration: 001, total loss=2725967298560.0000, content_loss=      0.0162, style loss=2725957920000.0000, tv loss=9560524.0000
# L-BFGS | iteration: 002, total loss=2725913034752.0000, content_loss=      0.4491, style loss=2725903680000.0000, tv loss=9560524.0000
# L-BFGS | iteration: 003, total loss=2725524537344.0000, content_loss=     20.9366, style loss=2725515120000.0000, tv loss=9560522.0000
# L-BFGS | iteration: 004, total loss=2721440071680.0000, content_loss=   2090.6545, style loss=2721430560000.0000, tv loss=9560467.0000
# L-BFGS | iteration: 005, total loss=2681224036352.0000, content_loss= 206319.4036, style loss=2681214240000.0000, tv loss=9559832.0000
# L-BFGS | iteration: 006, total loss=2335111118848.0000, content_loss=17723565.6738, style loss=2335083840000.0000, tv loss=9554450.0000
# Copying data/output-images/combined_big_campbells_soup_can_19c_the_starry_night/0006.jpg
# No video generated, skipping..
# Time elapsed: 21.467670917510986
#
# Processing content image: cats_named_sam_iv_61.jpg
# Processing style: the_starry_night.jpg
# Saving image as cats_named_sam_iv_61
# Using vgg19 in the optimization procedure.
# L-BFGS | iteration: 000, total loss=1608610611200.0000, content_loss=      0.0000, style loss=1608605760000.0000, tv loss=4898971.0000
# L-BFGS | iteration: 001, total loss=1608607072256.0000, content_loss=      0.0054, style loss=1608602280000.0000, tv loss=4898971.0000
# L-BFGS | iteration: 002, total loss=1608589770752.0000, content_loss=      0.1679, style loss=1608584880000.0000, tv loss=4898971.0000
# L-BFGS | iteration: 003, total loss=1608538652672.0000, content_loss=      1.9878, style loss=1608533760000.0000, tv loss=4898971.5000
# L-BFGS | iteration: 004, total loss=1607891419136.0000, content_loss=    198.3569, style loss=1607886600000.0000, tv loss=4899012.0000
# ^C
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 210, in <module>
#     results_path = neural_style_transfer(optimization_config)
#   File "neural_style_transfer.py", line 127, in neural_style_transfer
#     optimizer.step(closure)
#   File "/Users/iphra/opt/anaconda3/envs/pytorch-nst/lib/python3.7/site-packages/torch/optim/lbfgs.py", line 422, in step
#     obj_func, x_init, t, d, loss, flat_grad, gtd)
#   File "/Users/iphra/opt/anaconda3/envs/pytorch-nst/lib/python3.7/site-packages/torch/optim/lbfgs.py", line 98, in _strong_wolfe
#     f_new, g_new = obj_func(x, t, d)
#   File "/Users/iphra/opt/anaconda3/envs/pytorch-nst/lib/python3.7/site-packages/torch/optim/lbfgs.py", line 419, in obj_func
#     return self._directional_evaluate(closure, x, t, d)
#   File "/Users/iphra/opt/anaconda3/envs/pytorch-nst/lib/python3.7/site-packages/torch/optim/lbfgs.py", line 277, in _directional_evaluate
#     loss = float(closure())
#   File "neural_style_transfer.py", line 117, in closure
#     total_loss, content_loss, style_loss, tv_loss = build_loss(neural_net, optimizing_img, target_representations, content_feature_maps_index_name[0], style_feature_maps_indices_names[0], config)
#   File "neural_style_transfer.py", line 20, in build_loss
#     current_set_of_feature_maps = neural_net(optimizing_img)
#   File "/Users/iphra/opt/anaconda3/envs/pytorch-nst/lib/python3.7/site-packages/torch/nn/modules/module.py", line 532, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/Users/iphra/Projects/nftrip/models/definitions/vgg_nets.py", line 204, in forward
#     x = self.slice1(x)
#   File "/Users/iphra/opt/anaconda3/envs/pytorch-nst/lib/python3.7/site-packages/torch/nn/modules/module.py", line 532, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/Users/iphra/opt/anaconda3/envs/pytorch-nst/lib/python3.7/site-packages/torch/nn/modules/container.py", line 100, in forward
#     input = module(input)
#   File "/Users/iphra/opt/anaconda3/envs/pytorch-nst/lib/python3.7/site-packages/torch/nn/modules/module.py", line 532, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/Users/iphra/opt/anaconda3/envs/pytorch-nst/lib/python3.7/site-packages/torch/nn/modules/conv.py", line 345, in forward
#     return self.conv2d_forward(input, self.weight)
#   File "/Users/iphra/opt/anaconda3/envs/pytorch-nst/lib/python3.7/site-packages/torch/nn/modules/conv.py", line 342, in conv2d_forward
#     self.padding, self.dilation, self.groups)
# KeyboardInterrupt
#
# Processing content image: soup_can_tomato.jpg
# Processing style: the_starry_night.jpg
# Saving image as soup_can_tomato
