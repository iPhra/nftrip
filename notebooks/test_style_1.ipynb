# %%
import os
os.chdir('../')

# %%
import pandas as pd
from pathlib import Path
from PIL import Image
import json
import random

# %%
root_path = Path('./data/')

# %%
style_df = pd.read_csv(root_path / 'metadata' / 'style.csv')

content_df = pd.read_csv(root_path / 'metadata' / 'content.csv')

# %%
content_df.head()
# Out:
#                                        Title                 Author  \
# 0                  Big Campbell Soup Can 19C            Andy Warhol
# 1                          Cats Named Sam IV            Andy Warhol
# 2                            Soup Can Tomato            Andy Warhol
# 3                          Virgin Annunciate   Antonello da Messina
# 4  Self-Portrait as the Allegory of Painting  Artemisia Gentileschi
#
#   Orientation   Resolution                       File_name Notes
# 0    Portrait    598 × 800  big_campbells_soup_can_19c.jpg   NaN
# 1    Portrait    500 × 765        cats_named_sam_iv_61.jpg   NaN
# 2    Portrait  1596 × 2000             soup_can_tomato.jpg   NaN
# 3    Portrait      552x720                  annunciate.jpg   NaN
# 4    Portrait     818x1080                   allegorie.jpg   NaN

# %%
style_df.head()
# Out:
#                                   Title              Author  Resolution  \
# 0                 Bed of Chrysanthemums        Claude Monet    688x1024
# 1                         Blue Mountain   Wassily Kandinsky    947x1024
# 2                         Cocina Alpina     Ludwig Kirchner   1025x1024
# 3  Composition with Red Blue and Yellow       Piet Mondrian   1010x1024
# 4                      Composition VIII  Vasilij Kandinskij  1090 × 755
#
#                                      File_name  Notes
# 0                    bed_of_chrysanthemums.jpg  Luigi
# 1                           blue_mountain.jfif  Luigi
# 2                            cocina_alpina.jpg  Luigi
# 3  composition_II_with_red_blue_and_yellow.jpg  Luigi
# 4                         composition_viii.jpg    NaN

# %%
content_path = root_path / 'content-images'
style_path = root_path / 'style-images'

# %%
content = content_df[content_df.Title=='Mona Lisa'].iloc[0]
for j, style in style_df.iterrows():

    content_img_path = content_path / content['File_name']    
    style_img_path = style_path / style['File_name']
    output_name = f'{style["File_name"]}'.split('.')[0]

    print(f"Processing content image: {content['File_name']}")
    print(f"Processing style: {style['File_name']}")
    print(f"Saving image as {output_name}")
    
    try:
        # !python neural_style_transfer.py --content_img_name {content['File_name']} --style_img_name {style['File_name']} --output_img_name {output_name} --video {"False"} --output_path test_style1
    except:
        print(style['File_name'])
    
    print()
# Out:
# Processing content image: mona_lisa.jpeg
# Processing style: bed_of_chrysanthemums.jpg
# Saving image as bed_of_chrysanthemums
# Using vgg19 in the optimization procedure.
# L-BFGS | iteration: 000, total loss=1328475668480.0000, content_loss=      0.0000, style loss=1328465760000.0000, tv loss=10002612.0000
# L-BFGS | iteration: 001, total loss=1328474750976.0000, content_loss=      0.0012, style loss=1328464800000.0000, tv loss=10002612.0000
# L-BFGS | iteration: 002, total loss=1328469901312.0000, content_loss=      0.0246, style loss=1328459880000.0000, tv loss=10002612.0000
# L-BFGS | iteration: 003, total loss=1328443031552.0000, content_loss=      0.7220, style loss=1328433120000.0000, tv loss=10002612.0000
# L-BFGS | iteration: 004, total loss=1328283254784.0000, content_loss=     24.9782, style loss=1328273280000.0000, tv loss=10002620.0000
# L-BFGS | iteration: 005, total loss=1327417262080.0000, content_loss=    755.3850, style loss=1327407240000.0000, tv loss=10002720.0000
# L-BFGS | iteration: 006, total loss=1322662887424.0000, content_loss=  22810.7721, style loss=1322652960000.0000, tv loss=10003358.0000
# L-BFGS | iteration: 007, total loss=1272082857984.0000, content_loss=2152599.5255, style loss=1272070800000.0000, tv loss=10010128.0000
# L-BFGS | iteration: 008, total loss=1058296627200.0000, content_loss=49119000.2441, style loss=1058237520000.0000, tv loss=10057880.0000
# Copying data/output-images/combined_mona_lisa_bed_of_chrysanthemums/0008.jpg
# No video generated, skipping..
# Time elapsed: 22.923890829086304
#
# Processing content image: mona_lisa.jpeg
# Processing style: blue_mountain.jfif
# Saving image as blue_mountain
# Using vgg19 in the optimization procedure.
# L-BFGS | iteration: 000, total loss=1233392238592.0000, content_loss=      0.0000, style loss=1233382320000.0000, tv loss=10002612.0000
# L-BFGS | iteration: 001, total loss=1233391058944.0000, content_loss=      0.0014, style loss=1233381120000.0000, tv loss=10002612.0000
# L-BFGS | iteration: 002, total loss=1233384898560.0000, content_loss=      0.0311, style loss=1233374880000.0000, tv loss=10002612.0000
# L-BFGS | iteration: 003, total loss=1233367859200.0000, content_loss=      0.3292, style loss=1233357840000.0000, tv loss=10002612.0000
# L-BFGS | iteration: 004, total loss=1233148051456.0000, content_loss=     32.7686, style loss=1233138120000.0000, tv loss=10002552.0000
# L-BFGS | iteration: 005, total loss=1232048881664.0000, content_loss=    992.1945, style loss=1232038920000.0000, tv loss=10001844.0000
# L-BFGS | iteration: 006, total loss=1220102848512.0000, content_loss=  98766.1958, style loss=1220092800000.0000, tv loss=9994346.0000
# L-BFGS | iteration: 007, total loss=1114059177984.0000, content_loss=8967572.0215, style loss=1114040280000.0000, tv loss=9921214.0000
# Copying data/output-images/combined_mona_lisa_blue_mountain/0007.jpg
# No video generated, skipping..
# Time elapsed: 20.9780011177063
#
# Processing content image: mona_lisa.jpeg
# Processing style: cocina_alpina.jpg
# Saving image as cocina_alpina
# Using vgg19 in the optimization procedure.
# L-BFGS | iteration: 000, total loss=1476611538944.0000, content_loss=      0.0000, style loss=1476601560000.0000, tv loss=10002612.0000
# L-BFGS | iteration: 001, total loss=1476610228224.0000, content_loss=      0.0012, style loss=1476600240000.0000, tv loss=10002612.0000
# L-BFGS | iteration: 002, total loss=1476609179648.0000, content_loss=      0.0031, style loss=1476599280000.0000, tv loss=10002612.0000
# L-BFGS | iteration: 003, total loss=1476608000000.0000, content_loss=      0.0069, style loss=1476598080000.0000, tv loss=10002612.0000
# L-BFGS | iteration: 004, total loss=1476592795648.0000, content_loss=      0.1927, style loss=1476582840000.0000, tv loss=10002612.0000
# L-BFGS | iteration: 005, total loss=1476507992064.0000, content_loss=      5.8072, style loss=1476498000000.0000, tv loss=10002620.0000
# L-BFGS | iteration: 006, total loss=1476039933952.0000, content_loss=    175.7078, style loss=1476030000000.0000, tv loss=10002889.0000
# L-BFGS | iteration: 007, total loss=1470906630144.0000, content_loss=  17495.2686, style loss=1470896640000.0000, tv loss=10006445.0000
# L-BFGS | iteration: 008, total loss=1420919701504.0000, content_loss=1654075.4318, style loss=1420907880000.0000, tv loss=10040972.0000
# L-BFGS | iteration: 009, total loss=1048054923264.0000, content_loss=100712225.3418, style loss=1047943800000.0000, tv loss=10434588.0000
# Copying data/output-images/combined_mona_lisa_cocina_alpina/0009.jpg
# No video generated, skipping..
# Time elapsed: 24.99863910675049
#
# Processing content image: mona_lisa.jpeg
# Processing style: composition_II_with_red_blue_and_yellow.jpg
# Saving image as composition_II_with_red_blue_and_yellow
# Using vgg19 in the optimization procedure.
# L-BFGS | iteration: 000, total loss=1205093531648.0000, content_loss=      0.0000, style loss=1205083560000.0000, tv loss=10002612.0000
# L-BFGS | iteration: 001, total loss=1205092483072.0000, content_loss=      0.0011, style loss=1205082480000.0000, tv loss=10002612.0000
# L-BFGS | iteration: 002, total loss=1205087371264.0000, content_loss=      0.0231, style loss=1205077440000.0000, tv loss=10002612.0000
# L-BFGS | iteration: 003, total loss=1205071118336.0000, content_loss=      0.3014, style loss=1205061120000.0000, tv loss=10002612.0000
# L-BFGS | iteration: 004, total loss=1204969144320.0000, content_loss=      9.1127, style loss=1204959120000.0000, tv loss=10002590.0000
# L-BFGS | iteration: 005, total loss=1204176158720.0000, content_loss=    497.6275, style loss=1204166160000.0000, tv loss=10001798.0000
# ^C
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 210, in <module>
#     results_path = neural_style_transfer(optimization_config)
#   File "neural_style_transfer.py", line 127, in neural_style_transfer
#     optimizer.step(closure)
#   File "/Users/iphra/opt/anaconda3/envs/pytorch-nst/lib/python3.7/site-packages/torch/optim/lbfgs.py", line 422, in step
#     obj_func, x_init, t, d, loss, flat_grad, gtd)
#   File "/Users/iphra/opt/anaconda3/envs/pytorch-nst/lib/python3.7/site-packages/torch/optim/lbfgs.py", line 98, in _strong_wolfe
#     f_new, g_new = obj_func(x, t, d)
#   File "/Users/iphra/opt/anaconda3/envs/pytorch-nst/lib/python3.7/site-packages/torch/optim/lbfgs.py", line 419, in obj_func
#     return self._directional_evaluate(closure, x, t, d)
#   File "/Users/iphra/opt/anaconda3/envs/pytorch-nst/lib/python3.7/site-packages/torch/optim/lbfgs.py", line 277, in _directional_evaluate
#     loss = float(closure())
#   File "neural_style_transfer.py", line 117, in closure
#     total_loss, content_loss, style_loss, tv_loss = build_loss(neural_net, optimizing_img, target_representations, content_feature_maps_index_name[0], style_feature_maps_indices_names[0], config)
#   File "neural_style_transfer.py", line 20, in build_loss
#     current_set_of_feature_maps = neural_net(optimizing_img)
#   File "/Users/iphra/opt/anaconda3/envs/pytorch-nst/lib/python3.7/site-packages/torch/nn/modules/module.py", line 532, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/Users/iphra/Projects/nftrip/models/definitions/vgg_nets.py", line 208, in forward
#     x = self.slice3(x)
#   File "/Users/iphra/opt/anaconda3/envs/pytorch-nst/lib/python3.7/site-packages/torch/nn/modules/module.py", line 532, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/Users/iphra/opt/anaconda3/envs/pytorch-nst/lib/python3.7/site-packages/torch/nn/modules/container.py", line 100, in forward
#     input = module(input)
#   File "/Users/iphra/opt/anaconda3/envs/pytorch-nst/lib/python3.7/site-packages/torch/nn/modules/module.py", line 532, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/Users/iphra/opt/anaconda3/envs/pytorch-nst/lib/python3.7/site-packages/torch/nn/modules/conv.py", line 345, in forward
#     return self.conv2d_forward(input, self.weight)
#   File "/Users/iphra/opt/anaconda3/envs/pytorch-nst/lib/python3.7/site-packages/torch/nn/modules/conv.py", line 342, in conv2d_forward
#     self.padding, self.dilation, self.groups)
# KeyboardInterrupt
#
# Processing content image: mona_lisa.jpeg
# Processing style: composition_viii.jpg
# Saving image as composition_viii
# ^C
#
# Processing content image: mona_lisa.jpeg
# Processing style: crows.jpg
# Saving image as crows
# ^C
#
# Processing content image: mona_lisa.jpeg
# Processing style: dance_hall_bellevue.jpg
# Saving image as dance_hall_bellevue
# Using vgg19 in the optimization procedure.
# ^C
# Traceback (most recent call last):
#   File "neural_style_transfer.py", line 210, in <module>
#     results_path = neural_style_transfer(optimization_config)
#   File "neural_style_transfer.py", line 88, in neural_style_transfer
#     target_style_representation = [utils.gram_matrix(x) for cnt, x in enumerate(style_img_set_of_feature_maps) if cnt in style_feature_maps_indices_names[0]]
#   File "neural_style_transfer.py", line 88, in <listcomp>
#     target_style_representation = [utils.gram_matrix(x) for cnt, x in enumerate(style_img_set_of_feature_maps) if cnt in style_feature_maps_indices_names[0]]
#   File "/Users/iphra/Projects/nftrip/utils/utils.py", line 134, in gram_matrix
#     gram = features.bmm(features_t)
# KeyboardInterrupt
#
# Processing content image: mona_lisa.jpeg
# Processing style: edtaonisl.jpg
# Saving image as edtaonisl
