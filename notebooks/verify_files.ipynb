# %%
import os
os.chdir('../')

# %%
import pandas as pd
from pathlib import Path
from PIL import Image
import json
import random

# %%
root_path = Path('./data/')

# %%
style_df = pd.read_csv(root_path / 'metadata' / 'style.csv')

content_df = pd.read_csv(root_path / 'metadata' / 'content.csv')

# %%
content_df.head()
# Out:
#                                        Title                 Author  \
# 0                  Big Campbell Soup Can 19C            Andy Warhol
# 1                          Cats Named Sam IV            Andy Warhol
# 2                            Soup Can Tomato            Andy Warhol
# 3                          Virgin Annunciate   Antonello da Messina
# 4  Self-Portrait as the Allegory of Painting  Artemisia Gentileschi
#
#   Orientation   Resolution                       File_name Notes
# 0    Portrait    598 × 800  big_campbells_soup_can_19c.jpg   NaN
# 1    Portrait    500 × 765        cats_named_sam_iv_61.jpg   NaN
# 2    Portrait  1596 × 2000             soup_can_tomato.jpg   NaN
# 3    Portrait      552x720                  annunciate.jpg   NaN
# 4    Portrait     818x1080                   allegorie.jpg   NaN

# %%
style_df.head()
# Out:
#                          Title              Author  Resolution  \
# 0             Composition VIII  Vasilij Kandinskij  1090 × 755
# 1                    Edtaonisl     Francis Picabia     800x776
# 2                      Flowers           Ben Giles     512x512
# 3  Futuristic Composition 1914       Joseph Stella   750 × 566
# 4  The Great Wave off Kanagawa             Hokusai     485x485
#
#                     File_name  Notes
# 0        composition_viii.jpg    NaN
# 1               edtaonisl.jpg    NaN
# 2                 flowers.jpg    NaN
# 3  futuristic_composition.jpg    NaN
# 4              great_wave.jpg    NaN

# %%
content_path = root_path / 'content-images'
style_path = root_path / 'style-images'

metadata_path = root_path / 'output' / 'metadata'
metadata_path.mkdir(exist_ok=True, parents=True)

# %%
for i, content in content_df.iterrows():
    for j, style in style_df.iterrows():
        
        content_img_path = content_path / content['File_name']    
        style_img_path = style_path / style['File_name']
        
        if not content_img_path.exists():
            print(f"Error with image {content_img_path}")
        if not style_img_path.exists():
            print(f"Error with image {style_img_path}")
# Out:
# Error with image data/content-images/le_dejeuner_sur_l'herbe.jpg
# Error with image data/content-images/le_dejeuner_sur_l'herbe.jpg
# Error with image data/content-images/le_dejeuner_sur_l'herbe.jpg
# Error with image data/content-images/le_dejeuner_sur_l'herbe.jpg
# Error with image data/content-images/le_dejeuner_sur_l'herbe.jpg
# Error with image data/content-images/le_dejeuner_sur_l'herbe.jpg
# Error with image data/content-images/le_dejeuner_sur_l'herbe.jpg
# Error with image data/content-images/le_dejeuner_sur_l'herbe.jpg
# Error with image data/content-images/le_dejeuner_sur_l'herbe.jpg
# Error with image data/content-images/le_dejeuner_sur_l'herbe.jpg
# Error with image data/content-images/le_dejeuner_sur_l'herbe.jpg
# Error with image data/content-images/le_dejeuner_sur_l'herbe.jpg
# Error with image data/content-images/le_dejeuner_sur_l'herbe.jpg
# Error with image data/content-images/le_dejeuner_sur_l'herbe.jpg
# Error with image data/content-images/le_dejeuner_sur_l'herbe.jpg
# Error with image data/content-images/le_dejeuner_sur_l'herbe.jpg
# Error with image data/content-images/le_dejeuner_sur_l'herbe.jpg
# Error with image data/content-images/le_dejeuner_sur_l'herbe.jpg
# Error with image data/content-images/cape_cod_evening.jpg
# Error with image data/content-images/cape_cod_evening.jpg
# Error with image data/content-images/cape_cod_evening.jpg
# Error with image data/content-images/cape_cod_evening.jpg
# Error with image data/content-images/cape_cod_evening.jpg
# Error with image data/content-images/cape_cod_evening.jpg
# Error with image data/content-images/cape_cod_evening.jpg
# Error with image data/content-images/cape_cod_evening.jpg
# Error with image data/content-images/cape_cod_evening.jpg
# Error with image data/content-images/cape_cod_evening.jpg
# Error with image data/content-images/cape_cod_evening.jpg
# Error with image data/content-images/cape_cod_evening.jpg
# Error with image data/content-images/cape_cod_evening.jpg
# Error with image data/content-images/cape_cod_evening.jpg
# Error with image data/content-images/cape_cod_evening.jpg
# Error with image data/content-images/cape_cod_evening.jpg
# Error with image data/content-images/cape_cod_evening.jpg
# Error with image data/content-images/cape_cod_evening.jpg
# Error with image data/content-images/the_lighthouse_at_honfleur.jpg
# Error with image data/content-images/the_lighthouse_at_honfleur.jpg
# Error with image data/content-images/the_lighthouse_at_honfleur.jpg
# Error with image data/content-images/the_lighthouse_at_honfleur.jpg
# Error with image data/content-images/the_lighthouse_at_honfleur.jpg
# Error with image data/content-images/the_lighthouse_at_honfleur.jpg
# Error with image data/content-images/the_lighthouse_at_honfleur.jpg
# Error with image data/content-images/the_lighthouse_at_honfleur.jpg
# Error with image data/content-images/the_lighthouse_at_honfleur.jpg
# Error with image data/content-images/the_lighthouse_at_honfleur.jpg
# Error with image data/content-images/the_lighthouse_at_honfleur.jpg
# Error with image data/content-images/the_lighthouse_at_honfleur.jpg
# Error with image data/content-images/the_lighthouse_at_honfleur.jpg
# Error with image data/content-images/the_lighthouse_at_honfleur.jpg
# Error with image data/content-images/the_lighthouse_at_honfleur.jpg
# Error with image data/content-images/the_lighthouse_at_honfleur.jpg
# Error with image data/content-images/the_lighthouse_at_honfleur.jpg
# Error with image data/content-images/the_lighthouse_at_honfleur.jpg
