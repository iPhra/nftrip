# %%
import os
os.chdir('../')

# %%
import pandas as pd
from pathlib import Path
from PIL import Image
import json
import random

# %%
root_path = Path('./data/')

# %%
style_df = pd.read_csv(root_path / 'metadata' / 'style.csv')
style_df = style_df[~style_df['File_name'].isna()]
style_df = style_df.sort_values('File_name').reset_index(drop=True)

content_df = pd.read_csv(root_path / 'metadata' / 'content.csv')
content_df = content_df[~content_df['File_name'].isna()]
content_df = content_df.sort_values('File_name').reset_index(drop=True)

# %%
content_df.head()
# Out:
#                                        Title                 Author  \
# 0                Acrobat and young harlequin          Pablo Picasso
# 1                       The Creation of Adam           Michelangelo
# 2  Self-Portrait as the Allegory of Painting  Artemisia Gentileschi
# 3                            American Gothic             Grant Wood
# 4                          Amor Vincit Omnia             Caravaggio
#
#   Orientation  Resolution                        File_name Viene bene?
# 0    Portrait  684 × 1230  acrobat_and_young_harlequin.jpg         NaN
# 1   Landscape    1920x871                        adamo.jpg         NaN
# 2    Portrait    818x1080                    allegorie.jpg           Y
# 3    Portrait   1790x2160              american_gothic.jpg           Y
# 4    Portrait   1151x1614            amor_vincit_omnia.jpg         TBD

# %%
style_df.head()
# Out:
#                    Title             Author   Resolution  \
# 0  Bed of Chrysanthemums       Claude Monet     688x1024
# 1             Blue Horse         Marc Franz  1534 x 2048
# 2          Blue Mountain  Wassily Kandinsky     947x1024
# 3          The Blue Room      Pablo Picasso    1254x1024
# 4         Blue Black Fox         Marc Franz    1280x1015
#
#                    File_name  Notes  Strength
# 0  bed_of_chrysanthemums.jpg  Luigi       NaN
# 1             blue_horse.jpg    NaN       NaN
# 2         blue_mountain.jfif  Luigi       NaN
# 3              blue_room.jpg    NaN       NaN
# 4         blue-black_fox.jpg    NaN       NaN

# %%
content_path = root_path / 'content-images'
style_path = root_path / 'style-images'

# %%
content = content_df[content_df['File_name']=='la_reve.jpg'].iloc[0]
for j, style in style_df.iterrows():

    content_img_path = content_path / content['File_name']    
    style_img_path = style_path / style['File_name']
    output_name = f'{style["File_name"]}'.split('.')[0]

    print(f"Processing content image: {content['File_name']}")
    print(f"Processing style: {style['File_name']}")
    print(f"Saving image as {output_name}")
    
    try:
        # !python neural_style_transfer.py --content_img_name {content['File_name']} --style_img_name {style['File_name']} --output_img_name {output_name} --output_path test_style2
    except:
        print(style['File_name'])
    
    print()
# Out:
# Processing content image: la_reve.jpg
# Processing style: bed_of_chrysanthemums.jpg
# Saving image as bed_of_chrysanthemums
# 2021-12-04 16:17:30,711 [DEBUG] {'content_img_name': 'la_reve.jpg', 'style_img_name': 'bed_of_chrysanthemums.jpg', 'output_img_name': 'bed_of_chrysanthemums', 'output_path': 'test_style2', 'height': 500, 'content_weight': 100000.0, 'style_weight': 60000.0, 'tv_weight': 1.0, 'optimizer': 'lbfgs', 'model': 'vgg19', 'init_method': 'content', 'saving_freq': -1, 'content_images_dir': PosixPath('data/content-images'), 'style_images_dir': PosixPath('data/style-images'), 'output_img_dir': PosixPath('data/output-images'), 'images_path': PosixPath('data/test_style2/images'), 'gifs_path': PosixPath('data/test_style2/gifs'), 'img_format': (4, '.jpg')}
# 2021-12-04 16:17:30,712 [INFO] Starting training..
# 2021-12-04 16:17:31,281 [DEBUG] Using device cuda for training
# 2021-12-04 16:17:33,691 [DEBUG] Using vgg19 in the optimization procedure
# 2021-12-04 16:17:35,586 [DEBUG] Executed 4 iterations
# 2021-12-04 16:17:35,586 [INFO] Starting training..
# 2021-12-04 16:17:35,587 [DEBUG] Using device cuda for training
# 2021-12-04 16:17:36,796 [DEBUG] Using vgg19 in the optimization procedure
# 2021-12-04 16:19:41,192 [DEBUG] Executed 999 iterations
# 2021-12-04 16:19:41,192 [INFO] Training finished
# 2021-12-04 16:19:41,192 [INFO] Creating gif..
# 2021-12-04 16:19:52,303 [INFO] Copying data/output-images/combined_la_reve_bed_of_chrysanthemums/la_reve_bed_of_chrysanthemums_o_adam_i_content_h_500_m_vgg19_cw_100000.0_sw_60000.0_tv_1.0.jpg
# 2021-12-04 16:19:52,304 [INFO] Copying data/output-images/combined_la_reve_bed_of_chrysanthemums/out.gif
# 2021-12-04 16:19:52,304 [INFO] Copying to data/test_style2/gifs/gbed_of_chrysanthemums.gif
# 2021-12-04 16:19:52,350 [INFO] Time elapsed: 141.63963890075684
#
# Processing content image: la_reve.jpg
# Processing style: blue_horse.jpg
# Saving image as blue_horse
# 2021-12-04 16:19:53,767 [DEBUG] {'content_img_name': 'la_reve.jpg', 'style_img_name': 'blue_horse.jpg', 'output_img_name': 'blue_horse', 'output_path': 'test_style2', 'height': 500, 'content_weight': 100000.0, 'style_weight': 60000.0, 'tv_weight': 1.0, 'optimizer': 'lbfgs', 'model': 'vgg19', 'init_method': 'content', 'saving_freq': -1, 'content_images_dir': PosixPath('data/content-images'), 'style_images_dir': PosixPath('data/style-images'), 'output_img_dir': PosixPath('data/output-images'), 'images_path': PosixPath('data/test_style2/images'), 'gifs_path': PosixPath('data/test_style2/gifs'), 'img_format': (4, '.jpg')}
# 2021-12-04 16:19:53,767 [INFO] Starting training..
# 2021-12-04 16:19:54,330 [DEBUG] Using device cuda for training
# 2021-12-04 16:19:56,768 [DEBUG] Using vgg19 in the optimization procedure
# 2021-12-04 16:58:05,944 [DEBUG] Executed 1025 iterations
# 2021-12-04 16:58:05,944 [INFO] Training finished
# 2021-12-04 16:58:05,945 [INFO] Creating gif..
# 2021-12-04 16:58:16,913 [INFO] Copying data/output-images/combined_la_reve_flowers/la_reve_flowers_o_lbfgs_i_content_h_500_m_vgg19_cw_100000.0_sw_60000.0_tv_1.0.jpg
# 2021-12-04 16:58:16,913 [INFO] Copying data/output-images/combined_la_reve_flowers/out.gif
# 2021-12-04 16:58:16,913 [INFO] Copying to data/test_style2/gifs/gflowers.gif
# 2021-12-04 16:58:16,925 [INFO] Time elapsed: 167.0265884399414
#
# Processing content image: la_reve.jpg
# Processing style: futuristic_composition.jpg
# Saving image as futuristic_composition
# 2021-12-04 16:58:18,359 [DEBUG] {'content_img_name': 'la_reve.jpg', 'style_img_name': 'futuristic_composition.jpg', 'output_img_name': 'futuristic_composition', 'output_path': 'test_style2', 'height': 500, 'content_weight': 100000.0, 'style_weight': 60000.0, 'tv_weight': 1.0, 'optimizer': 'lbfgs', 'model': 'vgg19', 'init_method': 'content', 'saving_freq': -1, 'content_images_dir': PosixPath('data/content-images'), 'style_images_dir': PosixPath('data/style-images'), 'output_img_dir': PosixPath('data/output-images'), 'images_path': PosixPath('data/test_style2/images'), 'gifs_path': PosixPath('data/test_style2/gifs'), 'img_format': (4, '.jpg')}
# 2021-12-04 16:58:18,360 [INFO] Starting training..
# 2021-12-04 16:58:18,931 [DEBUG] Using device cuda for training
# 2021-12-04 16:58:21,398 [DEBUG] Using vgg19 in the optimization procedure
# 2021-12-04 17:00:55,946 [DEBUG] Executed 1019 iterations
# 2021-12-04 17:00:55,947 [INFO] Training finished
# 2021-12-04 17:00:55,947 [INFO] Creating gif..
